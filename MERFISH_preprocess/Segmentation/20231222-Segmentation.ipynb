# %%
#import torch
import os, sys, re, time
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
#import torch
print(os.getpid())
sys.path.append(r"/lab/weissman_imaging/puzheng/Softwares")
# Out:
# 3762601

# %%
import cv2
from ChromAn.src.file_io.data_organization import search_fovs_in_folders, Color_Usage
from ChromAn.src.segmentation_tools.cells import Align_Segmentation

# %%
import merlin
from merlin.util import watershed
from scipy import ndimage
from skimage import morphology
from skimage import segmentation
from copy import copy

# %%
# Cellpose 
from cellpose import models

# %% [markdown]
# ## Folders

# %%
# data_folder
data_folder = r'/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4'
# correction
correction_folder = r'/lab/weissman_imaging/puzheng/Corrections/20230902-Merscope01_s30_n500'

segmentation_save_folder = os.path.join(data_folder, 'Segmentation')
if not os.path.exists(segmentation_save_folder):
    print(segmentation_save_folder)
    os.makedirs(segmentation_save_folder)
watershed_folder = os.path.join(segmentation_save_folder, 'watershed')
if not os.path.exists(watershed_folder):
    print(watershed_folder)
    os.makedirs(watershed_folder)

# %%
# transpose with microscope
parameter_folder = r'/lab/weissman_imaging/puzheng/Softwares/Weissman_MERFISH_Scripts/merlin_parameters'
microscope_file = os.path.join(parameter_folder, 'microscope', 'merscope01_microscope.json')
microscope_params = Align_Segmentation._read_microscope_json(microscope_file)
microscope_params
# Out:
# {'flip_horizontal': False,
#  'flip_vertical': True,
#  'transpose': True,
#  'microns_per_pixel': 0.107,
#  'image_dimensions': [2304, 2304]}

# %%
# search folders
folders, fovs = search_fovs_in_folders(data_folder)
# Color usage file marks the organization of imaging files
color_usage_filename = os.path.join(data_folder, 'Analysis', 'color_usage.csv')
color_usage_df = Color_Usage(color_usage_filename)
# Out:
# - searching in folder: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4
# -- 9 folders, 543 fovs detected.
# - load color_usage from file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/Analysis/color_usage.csv

# %%
# from color_usage, find dapi / polyt / fiducial
dapi_info = color_usage_df.get_dapi_info()[0]
polyt_info = color_usage_df.get_polyt_info()[0]
fiducial_channel = color_usage_df.get_fiducial_channel(color_usage_df)
print(dapi_info, polyt_info, fiducial_channel)
# Out:
# {'hyb': 'H0M1', 'channel': '405'} {'channel': '637', 'hyb': 'H8M9'} 477

# %%
from ChromAn.src.file_io.dax_process import DaxProcesser
from ChromAn.src.visual_tools.interactive import imshow_mark_3d
from merlin.analysis.segment import CellPoseSegment
from importlib import reload
import ChromAn
reload(ChromAn.src.file_io.dax_process)

# %% [markdown]
# # Run segmentation

# %%
overwrite = True
ref_idx = 0

for _fov_id, _fov_name in enumerate(fovs):

    _save_id = _fov_id 
    seg_save_file = os.path.join(segmentation_save_folder, f'segmentation_label_{_save_id}.npy')
    if os.path.exists(seg_save_file) and not overwrite:
        print(f"Segmentation label file: {seg_save_file} already exists, skip")
        continue
    
    # find images
    ref_image_file = os.path.join(data_folder, color_usage_df.index[ref_idx], _fov_name)
    dapi_image_file = os.path.join(data_folder, dapi_info['hyb'], _fov_name)
    polyt_image_file = os.path.join(data_folder, polyt_info['hyb'], _fov_name)
    print(f"reference image: {ref_image_file}")
    print(f"PolyT image: {polyt_image_file}")
    print(f"DAPI image: {dapi_image_file}")
    
    # load reference DAPI
    _ref_cls = DaxProcesser(ref_image_file, CorrectionFolder=correction_folder, 
                            FiducialChannel=fiducial_channel, DapiChannel=dapi_info['channel'])
    _ref_cls._load_image(sel_channels=[fiducial_channel])
    _ref_cls._corr_illumination(correction_channels=[fiducial_channel])
    _ref_im = getattr(_ref_cls, f'im_{fiducial_channel}')

    # load dapi
    _dapi_cls = DaxProcesser(dapi_image_file, CorrectionFolder=correction_folder, 
                        FiducialChannel=fiducial_channel)
    _dapi_cls._load_image(sel_channels=[dapi_info['channel'],fiducial_channel])
    _dapi_cls.ref_correction_channel = '637'
    _dapi_cls._corr_illumination(correction_channels=[dapi_info['channel']])
    _dapi_cls._calculate_drift(_ref_im, )
    _dapi_cls._corr_warpping_drift_chromatic(correction_channels=[dapi_info['channel']], corr_chromatic=False) # removed 405 to increase efficiency
    _dapi_im = getattr(_dapi_cls, f"im_{dapi_info['channel']}")

    # load polyT
    _polyt_cls = DaxProcesser(polyt_image_file, CorrectionFolder=correction_folder, 
                        FiducialChannel=fiducial_channel)
    _polyt_cls._load_image(sel_channels=[polyt_info['channel'],fiducial_channel])
    _polyt_cls.ref_correction_channel = '637'
    _polyt_cls._corr_illumination(correction_channels=[polyt_info['channel']])
    _polyt_cls._calculate_drift(_ref_im, )
    _polyt_cls._corr_warpping_drift_chromatic(correction_channels=[polyt_info['channel']], corr_chromatic=False) # removed 405 to increase efficiency
    _polyt_im = getattr(_polyt_cls, f"im_{polyt_info['channel']}")
        
    # Run segmentation if target file not exist:
    if os.path.isfile(seg_save_file) and not overwrite:
        print(f"- directly load seg from: {seg_save_file}")
        corr_labels3d = np.load(seg_save_file)
    else:
        print(f"- apply microscope corrections")
        dapi_im = Align_Segmentation._correct_image3D_by_microscope_param(_dapi_im, microscope_params)
        polyt_im = Align_Segmentation._correct_image3D_by_microscope_param(_polyt_im, microscope_params)

        # Create cellpose model
        print(f"- run Cellpose segmentation", end=' ')
        _cellpose_start = time.time()
        seg_model = models.CellposeModel(gpu=True, model_type='tissuenet')
        # Run cellpose prediction
        labels3d, _, _ = seg_model.eval(np.stack([polyt_im, dapi_im], axis=3), 
                                        #batch_size=60, #anisotropy=250/108,
                                        anisotropy=1000/107,
                                        cellprob_threshold=0, 
                                        channels=[1,2], 
                                        diameter=50, 
                                        min_size=2000,
                                        do_3D=False,
                                        )
        print(f"in {time.time()-_cellpose_start:.3f}s.")

        # convert to corrected labels
        #corr_labels3d = CellPoseSegment.combine_2d_segmentation_masks_into_3d(labels3d)
        corr_labels3d = combine_2d_segmentation_masks_into_3d(labels3d)
        # save this segmentation mask
        print(f"- save to file: {seg_save_file}")
        np.save(seg_save_file.split('.npy')[0], corr_labels3d, )
    
    #break
# Out:
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_000.dax
# PolyT image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_000.dax
# DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_000.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_000.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_000_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477'] in 0.323s.
# - Correct illumination for channels: ['477']
# -- Keep channels: ['477'] for corr_illumination.
# - Start illumination correction for channels:['477'].
# -- loading illumination correction profile from file:
# 	 477 illumination_correction_477_2304x2304.npy
# -- corrected illumination for channel 477 in 0.934s.
# - Finished illumination correction in 0.945s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_000.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_000_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477', '405'] in 0.317s.
# - Correct illumination for channels: ['405']
# -- Keep channels: ['405'] for corr_illumination.
# - Start illumination correction for channels:['405'].
# -- loading illumination correction profile from file:
# 	 405 illumination_correction_405_2304x2304.npy
# -- corrected illumination for channel 405 in 0.932s.
# - Finished illumination correction in 0.942s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0. 0. 0.] in 0.513s.
# -- drift 1: [0. 0. 0.] in 0.541s.
# -- drift 2: [0. 0. 0.] in 0.543s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Warp drift and chromatic already finished, skip.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_000.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_000_processed.hdf5
# -- all used channels: ['748', '637', '477']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['637', '477'] in 0.272s.
# - Correct illumination for channels: ['637']
# -- Keep channels: ['637'] for corr_illumination.
# - Start illumination correction for channels:['637'].
# -- loading illumination correction profile from file:
# 	 637 illumination_correction_637_2304x2304.npy
# -- corrected illumination for channel 637 in 0.933s.
# - Finished illumination correction in 0.943s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [ 0.   -9.92  5.22] in 0.510s.
# -- drift 1: [-0.02 -9.54  5.83] in 0.541s.
# -- drift 2: [-0.01 -9.61  5.37] in 0.547s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 10.198s.
# - Finished warp correction in 10.198s.
# - apply microscope corrections
# - run Cellpose segmentation in 43.877s.
# 5 6
# 105
# [6, 5]
# 7 6
# 98
# [6, 5, 7]
# 4 5
# 105
# [6, 5, 7, 4]
# 8 7
# 90
# [6, 5, 7, 4, 8]
# 3 4
# 105
# [6, 5, 7, 4, 8, 3]
# 9 8
# 85
# [6, 5, 7, 4, 8, 3, 9]
# 2 3
# 100
# [6, 5, 7, 4, 8, 3, 9, 2]
# 10 9
# 76
# [6, 5, 7, 4, 8, 3, 9, 2, 10]
# 1 2
# 93
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1]
# 11 10
# 66
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11]
# 0 1
# 81
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0]
# 12 11
# 64
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0, 12]
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/Segmentation/segmentation_label_0.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_001.dax
# PolyT image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_001.dax
# DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_001.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_001.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_001_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477'] in 0.301s.
# - Correct illumination for channels: ['477']
# -- Keep channels: ['477'] for corr_illumination.
# - Start illumination correction for channels:['477'].
# -- loading illumination correction profile from file:
# 	 477 illumination_correction_477_2304x2304.npy
# -- corrected illumination for channel 477 in 0.933s.
# - Finished illumination correction in 0.944s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_001.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_001_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477', '405'] in 0.321s.
# - Correct illumination for channels: ['405']
# -- Keep channels: ['405'] for corr_illumination.
# - Start illumination correction for channels:['405'].
# -- loading illumination correction profile from file:
# 	 405 illumination_correction_405_2304x2304.npy
# -- corrected illumination for channel 405 in 0.933s.
# - Finished illumination correction in 0.943s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0. 0. 0.] in 0.518s.
# -- drift 1: [0. 0. 0.] in 0.545s.
# -- drift 2: [0. 0. 0.] in 0.540s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Warp drift and chromatic already finished, skip.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_001.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_001_processed.hdf5
# -- all used channels: ['748', '637', '477']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['637', '477'] in 0.283s.
# - Correct illumination for channels: ['637']
# -- Keep channels: ['637'] for corr_illumination.
# - Start illumination correction for channels:['637'].
# -- loading illumination correction profile from file:
# 	 637 illumination_correction_637_2304x2304.npy
# -- corrected illumination for channel 637 in 0.933s.
# - Finished illumination correction in 0.943s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [ 0.   -2.74  8.02] in 0.515s.
# -- drift 1: [ 0.   -2.59  7.93] in 0.543s.
# -- drift 2: [ 0.   -2.7   7.94] in 0.542s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 10.201s.
# - Finished warp correction in 10.201s.
# - apply microscope corrections
# - run Cellpose segmentation in 48.040s.
# 5 6
# 125
# [6, 5]
# 7 6
# 109
# [6, 5, 7]
# 4 5
# 122
# [6, 5, 7, 4]
# 8 7
# 105
# [6, 5, 7, 4, 8]
# 3 4
# 130
# [6, 5, 7, 4, 8, 3]
# 9 8
# 98
# [6, 5, 7, 4, 8, 3, 9]
# 2 3
# 116
# [6, 5, 7, 4, 8, 3, 9, 2]
# 10 9
# 88
# [6, 5, 7, 4, 8, 3, 9, 2, 10]
# 1 2
# 104
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1]
# 11 10
# 81
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11]
# 0 1
# 101
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0]
# 12 11
# 72
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0, 12]
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/Segmentation/segmentation_label_1.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_002.dax
# PolyT image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_002.dax
# DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_002.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_002.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_002_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477'] in 0.303s.
# - Correct illumination for channels: ['477']
# -- Keep channels: ['477'] for corr_illumination.
# - Start illumination correction for channels:['477'].
# -- loading illumination correction profile from file:
# 	 477 illumination_correction_477_2304x2304.npy
# -- corrected illumination for channel 477 in 0.932s.
# - Finished illumination correction in 0.943s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_002.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_002_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477', '405'] in 0.317s.
# - Correct illumination for channels: ['405']
# -- Keep channels: ['405'] for corr_illumination.
# - Start illumination correction for channels:['405'].
# -- loading illumination correction profile from file:
# 	 405 illumination_correction_405_2304x2304.npy
# -- corrected illumination for channel 405 in 0.933s.
# - Finished illumination correction in 0.943s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0. 0. 0.] in 0.522s.
# -- drift 1: [0. 0. 0.] in 0.553s.
# -- drift 2: [0. 0. 0.] in 0.558s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Warp drift and chromatic already finished, skip.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_002.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_002_processed.hdf5
# -- all used channels: ['748', '637', '477']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['637', '477'] in 0.283s.
# - Correct illumination for channels: ['637']
# -- Keep channels: ['637'] for corr_illumination.
# - Start illumination correction for channels:['637'].
# -- loading illumination correction profile from file:
# 	 637 illumination_correction_637_2304x2304.npy
# -- corrected illumination for channel 637 in 0.931s.
# - Finished illumination correction in 0.941s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.02 -1.19  7.47] in 0.531s.
# -- drift 1: [-0.02 -1.24  7.5 ] in 0.557s.
# -- drift 2: [-0.02 -1.29  7.54] in 0.557s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 10.207s.
# - Finished warp correction in 10.207s.
# - apply microscope corrections
# - run Cellpose segmentation in 47.378s.
# 5 6
# 143
# [6, 5]
# 7 6
# 138
# [6, 5, 7]
# 4 5
# 138
# [6, 5, 7, 4]
# 8 7
# 126
# [6, 5, 7, 4, 8]
# 3 4
# 149
# [6, 5, 7, 4, 8, 3]
# 9 8
# 119
# [6, 5, 7, 4, 8, 3, 9]
# 2 3
# 153
# [6, 5, 7, 4, 8, 3, 9, 2]
# 10 9
# 110
# [6, 5, 7, 4, 8, 3, 9, 2, 10]
# 1 2
# 146
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1]
# 11 10
# 97
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11]
# 0 1
# 131
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0]
# 12 11
# 79
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0, 12]
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/Segmentation/segmentation_label_2.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_003.dax
# PolyT image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_003.dax
# DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_003.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_003.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_003_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477'] in 0.298s.
# - Correct illumination for channels: ['477']
# -- Keep channels: ['477'] for corr_illumination.
# - Start illumination correction for channels:['477'].
# -- loading illumination correction profile from file:
# 	 477 illumination_correction_477_2304x2304.npy
# -- corrected illumination for channel 477 in 0.935s.
# - Finished illumination correction in 0.946s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_003.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_003_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477', '405'] in 0.317s.
# - Correct illumination for channels: ['405']
# -- Keep channels: ['405'] for corr_illumination.
# - Start illumination correction for channels:['405'].
# -- loading illumination correction profile from file:
# 	 405 illumination_correction_405_2304x2304.npy
# -- corrected illumination for channel 405 in 0.933s.
# - Finished illumination correction in 0.943s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0. 0. 0.] in 0.516s.
# -- drift 1: [0. 0. 0.] in 0.543s.
# -- drift 2: [0. 0. 0.] in 0.540s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Warp drift and chromatic already finished, skip.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_003.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_003_processed.hdf5
# -- all used channels: ['748', '637', '477']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['637', '477'] in 0.283s.
# - Correct illumination for channels: ['637']
# -- Keep channels: ['637'] for corr_illumination.
# - Start illumination correction for channels:['637'].
# -- loading illumination correction profile from file:
# 	 637 illumination_correction_637_2304x2304.npy
# -- corrected illumination for channel 637 in 0.932s.
# - Finished illumination correction in 0.942s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.02 -0.63  8.47] in 0.516s.
# -- drift 1: [-0.04 -0.63  8.31] in 0.543s.
# -- drift 2: [-0.04 -0.7   8.32] in 0.547s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 10.217s.
# - Finished warp correction in 10.218s.
# - apply microscope corrections
# - run Cellpose segmentation in 44.843s.
# 5 6
# 118
# [6, 5]
# 7 6
# 102
# [6, 5, 7]
# 4 5
# 119
# [6, 5, 7, 4]
# 8 7
# 102
# [6, 5, 7, 4, 8]
# 3 4
# 119
# [6, 5, 7, 4, 8, 3]
# 9 8
# 91
# [6, 5, 7, 4, 8, 3, 9]
# 2 3
# 120
# [6, 5, 7, 4, 8, 3, 9, 2]
# 10 9
# 85
# [6, 5, 7, 4, 8, 3, 9, 2, 10]
# 1 2
# 116
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1]
# 11 10
# 81
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11]
# 0 1
# 113
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0]
# 12 11
# 68
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0, 12]
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/Segmentation/segmentation_label_3.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_004.dax
# PolyT image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_004.dax
# DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_004.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_004.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_004_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477'] in 2.157s.
# - Correct illumination for channels: ['477']
# -- Keep channels: ['477'] for corr_illumination.
# - Start illumination correction for channels:['477'].
# -- loading illumination correction profile from file:
# 	 477 illumination_correction_477_2304x2304.npy
# -- corrected illumination for channel 477 in 1.122s.
# - Finished illumination correction in 1.138s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_004.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_004_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477', '405'] in 0.330s.
# - Correct illumination for channels: ['405']
# -- Keep channels: ['405'] for corr_illumination.
# - Start illumination correction for channels:['405'].
# -- loading illumination correction profile from file:
# 	 405 illumination_correction_405_2304x2304.npy
# -- corrected illumination for channel 405 in 0.933s.
# - Finished illumination correction in 0.943s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0. 0. 0.] in 0.516s.
# -- drift 1: [0. 0. 0.] in 0.545s.
# -- drift 2: [0. 0. 0.] in 0.546s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Warp drift and chromatic already finished, skip.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_004.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_004_processed.hdf5
# -- all used channels: ['748', '637', '477']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.971s.
# - Correct illumination for channels: ['637']
# -- Keep channels: ['637'] for corr_illumination.
# - Start illumination correction for channels:['637'].
# -- loading illumination correction profile from file:
# 	 637 illumination_correction_637_2304x2304.npy
# -- corrected illumination for channel 637 in 0.932s.
# - Finished illumination correction in 0.942s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.   0.11 9.67] in 0.512s.
# -- drift 1: [-0.03  0.16  9.98] in 0.542s.
# -- drift 2: [-0.05  0.17 10.11] in 0.546s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 10.188s.
# - Finished warp correction in 10.189s.
# - apply microscope corrections
# - run Cellpose segmentation in 42.490s.
# 5 6
# 79
# [6, 5]
# 7 6
# 74
# [6, 5, 7]
# 4 5
# 77
# [6, 5, 7, 4]
# 8 7
# 67
# [6, 5, 7, 4, 8]
# 3 4
# 79
# [6, 5, 7, 4, 8, 3]
# 9 8
# 64
# [6, 5, 7, 4, 8, 3, 9]
# 2 3
# 80
# [6, 5, 7, 4, 8, 3, 9, 2]
# 10 9
# 59
# [6, 5, 7, 4, 8, 3, 9, 2, 10]
# 1 2
# 78
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1]
# 11 10
# 54
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11]
# 0 1
# 72
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0]
# 12 11
# 44
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0, 12]
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/Segmentation/segmentation_label_4.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_005.dax
# PolyT image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_005.dax
# DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_005.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_005.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_005_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477'] in 2.498s.
# - Correct illumination for channels: ['477']
# -- Keep channels: ['477'] for corr_illumination.
# - Start illumination correction for channels:['477'].
# -- loading illumination correction profile from file:
# 	 477 illumination_correction_477_2304x2304.npy
# -- corrected illumination for channel 477 in 1.040s.
# - Finished illumination correction in 1.056s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_005.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_005_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477', '405'] in 0.327s.
# - Correct illumination for channels: ['405']
# -- Keep channels: ['405'] for corr_illumination.
# - Start illumination correction for channels:['405'].
# -- loading illumination correction profile from file:
# 	 405 illumination_correction_405_2304x2304.npy
# -- corrected illumination for channel 405 in 0.922s.
# - Finished illumination correction in 0.933s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0. 0. 0.] in 0.512s.
# -- drift 1: [0. 0. 0.] in 0.545s.
# -- drift 2: [0. 0. 0.] in 0.545s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Warp drift and chromatic already finished, skip.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_005.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_005_processed.hdf5
# -- all used channels: ['748', '637', '477']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.759s.
# - Correct illumination for channels: ['637']
# -- Keep channels: ['637'] for corr_illumination.
# - Start illumination correction for channels:['637'].
# -- loading illumination correction profile from file:
# 	 637 illumination_correction_637_2304x2304.npy
# -- corrected illumination for channel 637 in 0.934s.
# - Finished illumination correction in 0.945s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.02 -0.4   8.65] in 0.513s.
# -- drift 1: [-0.02 -0.77  9.06] in 0.547s.
# -- drift 2: [-0.03 -0.83  9.17] in 0.546s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 10.213s.
# - Finished warp correction in 10.213s.
# - apply microscope corrections
# - run Cellpose segmentation in 44.608s.
# 5 6
# 55
# [6, 5]
# 7 6
# 45
# [6, 5, 7]
# 4 5
# 60
# [6, 5, 7, 4]
# 8 7
# 38
# [6, 5, 7, 4, 8]
# 3 4
# 62
# [6, 5, 7, 4, 8, 3]
# 9 8
# 35
# [6, 5, 7, 4, 8, 3, 9]
# 2 3
# 67
# [6, 5, 7, 4, 8, 3, 9, 2]
# 10 9
# 29
# [6, 5, 7, 4, 8, 3, 9, 2, 10]
# 1 2
# 64
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1]
# 11 10
# 26
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11]
# 0 1
# 58
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0]
# 12 11
# 23
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0, 12]
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/Segmentation/segmentation_label_5.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_006.dax
# PolyT image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_006.dax
# DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_006.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_006.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_006_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477'] in 2.302s.
# - Correct illumination for channels: ['477']
# -- Keep channels: ['477'] for corr_illumination.
# - Start illumination correction for channels:['477'].
# -- loading illumination correction profile from file:
# 	 477 illumination_correction_477_2304x2304.npy
# -- corrected illumination for channel 477 in 1.130s.
# - Finished illumination correction in 1.147s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_006.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_006_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477', '405'] in 0.331s.
# - Correct illumination for channels: ['405']
# -- Keep channels: ['405'] for corr_illumination.
# - Start illumination correction for channels:['405'].
# -- loading illumination correction profile from file:
# 	 405 illumination_correction_405_2304x2304.npy
# -- corrected illumination for channel 405 in 0.933s.
# - Finished illumination correction in 0.943s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0. 0. 0.] in 0.527s.
# -- drift 1: [0. 0. 0.] in 0.560s.
# -- drift 2: [0. 0. 0.] in 0.555s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Warp drift and chromatic already finished, skip.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_006.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_006_processed.hdf5
# -- all used channels: ['748', '637', '477']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.747s.
# - Correct illumination for channels: ['637']
# -- Keep channels: ['637'] for corr_illumination.
# - Start illumination correction for channels:['637'].
# -- loading illumination correction profile from file:
# 	 637 illumination_correction_637_2304x2304.npy
# -- corrected illumination for channel 637 in 0.945s.
# - Finished illumination correction in 0.956s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.01  0.1   8.33] in 0.528s.
# -- drift 1: [-0.06  0.3   8.3 ] in 0.560s.
# -- drift 2: [-0.03  0.72  8.17] in 0.561s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 10.243s.
# - Finished warp correction in 10.243s.
# - apply microscope corrections
# - run Cellpose segmentation in 44.691s.
# 5 6
# 15
# [6, 5]
# 7 6
# 8
# [6, 5, 7]
# 4 5
# 8
# [6, 5, 7, 4]
# 8 7
# 5
# [6, 5, 7, 4, 8]
# 3 4
# 11
# [6, 5, 7, 4, 8, 3]
# 9 8
# 6
# [6, 5, 7, 4, 8, 3, 9]
# 2 3
# 9
# [6, 5, 7, 4, 8, 3, 9, 2]
# 10 9
# 3
# [6, 5, 7, 4, 8, 3, 9, 2, 10]
# 1 2
# 8
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1]
# 11 10
# 2
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11]
# 0 1
# 8
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0]
# 12 11
# 1
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0, 12]
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/Segmentation/segmentation_label_6.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_007.dax
# PolyT image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_007.dax
# DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_007.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_007.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_007_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477'] in 2.214s.
# - Correct illumination for channels: ['477']
# -- Keep channels: ['477'] for corr_illumination.
# - Start illumination correction for channels:['477'].
# -- loading illumination correction profile from file:
# 	 477 illumination_correction_477_2304x2304.npy
# -- corrected illumination for channel 477 in 1.137s.
# - Finished illumination correction in 1.153s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_007.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_007_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477', '405'] in 0.335s.
# - Correct illumination for channels: ['405']
# -- Keep channels: ['405'] for corr_illumination.
# - Start illumination correction for channels:['405'].
# -- loading illumination correction profile from file:
# 	 405 illumination_correction_405_2304x2304.npy
# -- corrected illumination for channel 405 in 0.941s.
# - Finished illumination correction in 0.952s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0. 0. 0.] in 0.515s.
# -- drift 1: [0. 0. 0.] in 0.551s.
# -- drift 2: [0. 0. 0.] in 0.548s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Warp drift and chromatic already finished, skip.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_007.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_007_processed.hdf5
# -- all used channels: ['748', '637', '477']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.616s.
# - Correct illumination for channels: ['637']
# -- Keep channels: ['637'] for corr_illumination.
# - Start illumination correction for channels:['637'].
# -- loading illumination correction profile from file:
# 	 637 illumination_correction_637_2304x2304.npy
# -- corrected illumination for channel 637 in 0.931s.
# - Finished illumination correction in 0.941s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.01 1.35 9.25] in 0.511s.
# -- drift 1: [-0.03  1.56  9.34] in 0.550s.
# -- drift 2: [-0.03  1.36  9.65] in 0.544s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 10.206s.
# - Finished warp correction in 10.206s.
# - apply microscope corrections
# - run Cellpose segmentation in 47.659s.
# 5 6
# 15
# [6, 5]
# 7 6
# 13
# [6, 5, 7]
# 4 5
# 23
# [6, 5, 7, 4]
# 8 7
# 11
# [6, 5, 7, 4, 8]
# 3 4
# 14
# [6, 5, 7, 4, 8, 3]
# 9 8
# 16
# [6, 5, 7, 4, 8, 3, 9]
# 2 3
# 17
# [6, 5, 7, 4, 8, 3, 9, 2]
# 10 9
# 10
# [6, 5, 7, 4, 8, 3, 9, 2, 10]
# 1 2
# 16
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1]
# 11 10
# 8
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11]
# 0 1
# 13
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0]
# 12 11
# 8
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0, 12]
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/Segmentation/segmentation_label_7.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_008.dax
# PolyT image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_008.dax
# DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_008.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_008.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_008_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477'] in 2.194s.
# - Correct illumination for channels: ['477']
# -- Keep channels: ['477'] for corr_illumination.
# - Start illumination correction for channels:['477'].
# -- loading illumination correction profile from file:
# 	 477 illumination_correction_477_2304x2304.npy
# -- corrected illumination for channel 477 in 1.126s.
# - Finished illumination correction in 1.143s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_008.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_008_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477', '405'] in 0.331s.
# - Correct illumination for channels: ['405']
# -- Keep channels: ['405'] for corr_illumination.
# - Start illumination correction for channels:['405'].
# -- loading illumination correction profile from file:
# 	 405 illumination_correction_405_2304x2304.npy
# -- corrected illumination for channel 405 in 0.940s.
# - Finished illumination correction in 0.950s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0. 0. 0.] in 0.516s.
# -- drift 1: [0. 0. 0.] in 0.545s.
# -- drift 2: [0. 0. 0.] in 0.546s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Warp drift and chromatic already finished, skip.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_008.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_008_processed.hdf5
# -- all used channels: ['748', '637', '477']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.827s.
# - Correct illumination for channels: ['637']
# -- Keep channels: ['637'] for corr_illumination.
# - Start illumination correction for channels:['637'].
# -- loading illumination correction profile from file:
# 	 637 illumination_correction_637_2304x2304.npy
# -- corrected illumination for channel 637 in 0.932s.
# - Finished illumination correction in 0.943s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [ 0.    0.5  10.53] in 0.512s.
# -- drift 1: [ 0.    0.45 10.46] in 0.545s.
# -- drift 2: [1.000e-02 5.100e-01 1.056e+01] in 0.548s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 10.197s.
# - Finished warp correction in 10.197s.
# - apply microscope corrections
# - run Cellpose segmentation in 44.130s.
# 5 6
# 28
# [6, 5]
# 7 6
# 31
# [6, 5, 7]
# 4 5
# 36
# [6, 5, 7, 4]
# 8 7
# 30
# [6, 5, 7, 4, 8]
# 3 4
# 40
# [6, 5, 7, 4, 8, 3]
# 9 8
# 29
# [6, 5, 7, 4, 8, 3, 9]
# 2 3
# 49
# [6, 5, 7, 4, 8, 3, 9, 2]
# 10 9
# 23
# [6, 5, 7, 4, 8, 3, 9, 2, 10]
# 1 2
# 53
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1]
# 11 10
# 24
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11]
# 0 1
# 56
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0]
# 12 11
# 19
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0, 12]
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/Segmentation/segmentation_label_8.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_009.dax
# PolyT image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_009.dax
# DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_009.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_009.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_009_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477'] in 2.171s.
# - Correct illumination for channels: ['477']
# -- Keep channels: ['477'] for corr_illumination.
# - Start illumination correction for channels:['477'].
# -- loading illumination correction profile from file:
# 	 477 illumination_correction_477_2304x2304.npy
# -- corrected illumination for channel 477 in 1.115s.
# - Finished illumination correction in 1.131s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_009.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_009_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477', '405'] in 0.328s.
# - Correct illumination for channels: ['405']
# -- Keep channels: ['405'] for corr_illumination.
# - Start illumination correction for channels:['405'].
# -- loading illumination correction profile from file:
# 	 405 illumination_correction_405_2304x2304.npy
# -- corrected illumination for channel 405 in 0.923s.
# - Finished illumination correction in 0.933s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0. 0. 0.] in 0.510s.
# -- drift 1: [0. 0. 0.] in 0.545s.
# -- drift 2: [0. 0. 0.] in 0.542s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Warp drift and chromatic already finished, skip.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_009.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_009_processed.hdf5
# -- all used channels: ['748', '637', '477']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.892s.
# - Correct illumination for channels: ['637']
# -- Keep channels: ['637'] for corr_illumination.
# - Start illumination correction for channels:['637'].
# -- loading illumination correction profile from file:
# 	 637 illumination_correction_637_2304x2304.npy
# -- corrected illumination for channel 637 in 0.933s.
# - Finished illumination correction in 0.944s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.02 2.36 9.23] in 0.516s.
# -- drift 1: [0.   2.33 9.68] in 0.544s.
# -- drift 2: [0.   2.33 9.64] in 0.551s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 10.220s.
# - Finished warp correction in 10.220s.
# - apply microscope corrections
# - run Cellpose segmentation in 38.651s.
# 5 6
# 78
# [6, 5]
# 7 6
# 74
# [6, 5, 7]
# 4 5
# 80
# [6, 5, 7, 4]
# 8 7
# 72
# [6, 5, 7, 4, 8]
# 3 4
# 80
# [6, 5, 7, 4, 8, 3]
# 9 8
# 73
# [6, 5, 7, 4, 8, 3, 9]
# 2 3
# 78
# [6, 5, 7, 4, 8, 3, 9, 2]
# 10 9
# 69
# [6, 5, 7, 4, 8, 3, 9, 2, 10]
# 1 2
# 75
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1]
# 11 10
# 65
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11]
# 0 1
# 67
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0]
# 12 11
# 55
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0, 12]
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/Segmentation/segmentation_label_9.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_010.dax
# PolyT image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_010.dax
# DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_010.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_010.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_010_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477'] in 2.214s.
# - Correct illumination for channels: ['477']
# -- Keep channels: ['477'] for corr_illumination.
# - Start illumination correction for channels:['477'].
# -- loading illumination correction profile from file:
# 	 477 illumination_correction_477_2304x2304.npy
# -- corrected illumination for channel 477 in 1.123s.
# - Finished illumination correction in 1.139s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_010.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_010_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477', '405'] in 0.329s.
# - Correct illumination for channels: ['405']
# -- Keep channels: ['405'] for corr_illumination.
# - Start illumination correction for channels:['405'].
# -- loading illumination correction profile from file:
# 	 405 illumination_correction_405_2304x2304.npy
# -- corrected illumination for channel 405 in 0.934s.
# - Finished illumination correction in 0.944s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0. 0. 0.] in 0.514s.
# -- drift 1: [0. 0. 0.] in 0.549s.
# -- drift 2: [0. 0. 0.] in 0.544s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Warp drift and chromatic already finished, skip.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_010.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_010_processed.hdf5
# -- all used channels: ['748', '637', '477']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.719s.
# - Correct illumination for channels: ['637']
# -- Keep channels: ['637'] for corr_illumination.
# - Start illumination correction for channels:['637'].
# -- loading illumination correction profile from file:
# 	 637 illumination_correction_637_2304x2304.npy
# -- corrected illumination for channel 637 in 0.933s.
# - Finished illumination correction in 0.943s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.01  0.82  6.96] in 0.516s.
# -- drift 1: [-0.01  1.25  6.65] in 0.547s.
# -- drift 2: [-0.02  0.82  6.9 ] in 0.551s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 10.207s.
# - Finished warp correction in 10.208s.
# - apply microscope corrections
# - run Cellpose segmentation in 45.525s.
# 5 6
# 99
# [6, 5]
# 7 6
# 107
# [6, 5, 7]
# 4 5
# 97
# [6, 5, 7, 4]
# 8 7
# 99
# [6, 5, 7, 4, 8]
# 3 4
# 98
# [6, 5, 7, 4, 8, 3]
# 9 8
# 93
# [6, 5, 7, 4, 8, 3, 9]
# 2 3
# 96
# [6, 5, 7, 4, 8, 3, 9, 2]
# 10 9
# 90
# [6, 5, 7, 4, 8, 3, 9, 2, 10]
# 1 2
# 95
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1]
# 11 10
# 88
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11]
# 0 1
# 100
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0]
# 12 11
# 83
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0, 12]
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/Segmentation/segmentation_label_10.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_011.dax
# PolyT image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_011.dax
# DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_011.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_011.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_011_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477'] in 2.510s.
# - Correct illumination for channels: ['477']
# -- Keep channels: ['477'] for corr_illumination.
# - Start illumination correction for channels:['477'].
# -- loading illumination correction profile from file:
# 	 477 illumination_correction_477_2304x2304.npy
# -- corrected illumination for channel 477 in 1.135s.
# - Finished illumination correction in 1.151s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_011.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_011_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477', '405'] in 0.329s.
# - Correct illumination for channels: ['405']
# -- Keep channels: ['405'] for corr_illumination.
# - Start illumination correction for channels:['405'].
# -- loading illumination correction profile from file:
# 	 405 illumination_correction_405_2304x2304.npy
# -- corrected illumination for channel 405 in 0.933s.
# - Finished illumination correction in 0.943s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0. 0. 0.] in 0.517s.
# -- drift 1: [0. 0. 0.] in 0.544s.
# -- drift 2: [0. 0. 0.] in 0.549s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Warp drift and chromatic already finished, skip.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_011.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_011_processed.hdf5
# -- all used channels: ['748', '637', '477']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.746s.
# - Correct illumination for channels: ['637']
# -- Keep channels: ['637'] for corr_illumination.
# - Start illumination correction for channels:['637'].
# -- loading illumination correction profile from file:
# 	 637 illumination_correction_637_2304x2304.npy
# -- corrected illumination for channel 637 in 0.932s.
# - Finished illumination correction in 0.942s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.01  1.98  8.73] in 0.519s.
# -- drift 1: [-0.01  1.97  8.77] in 0.547s.
# -- drift 2: [-0.02  1.97  8.85] in 0.546s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 10.248s.
# - Finished warp correction in 10.248s.
# - apply microscope corrections
# - run Cellpose segmentation in 49.457s.
# 5 6
# 131
# [6, 5]
# 7 6
# 108
# [6, 5, 7]
# 4 5
# 140
# [6, 5, 7, 4]
# 8 7
# 102
# [6, 5, 7, 4, 8]
# 3 4
# 143
# [6, 5, 7, 4, 8, 3]
# 9 8
# 90
# [6, 5, 7, 4, 8, 3, 9]
# 2 3
# 146
# [6, 5, 7, 4, 8, 3, 9, 2]
# 10 9
# 89
# [6, 5, 7, 4, 8, 3, 9, 2, 10]
# 1 2
# 138
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1]
# 11 10
# 85
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11]
# 0 1
# 128
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0]
# 12 11
# 82
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0, 12]
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/Segmentation/segmentation_label_11.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_012.dax
# PolyT image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_012.dax
# DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_012.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_012.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_012_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477'] in 2.255s.
# - Correct illumination for channels: ['477']
# -- Keep channels: ['477'] for corr_illumination.
# - Start illumination correction for channels:['477'].
# -- loading illumination correction profile from file:
# 	 477 illumination_correction_477_2304x2304.npy
# -- corrected illumination for channel 477 in 1.123s.
# - Finished illumination correction in 1.139s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_012.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_012_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477', '405'] in 0.330s.
# - Correct illumination for channels: ['405']
# ...
# 5 6
# 111
# [6, 5]
# 7 6
# 88
# [6, 5, 7]
# 4 5
# 125
# [6, 5, 7, 4]
# 8 7
# 81
# [6, 5, 7, 4, 8]
# 3 4
# 127
# [6, 5, 7, 4, 8, 3]
# 9 8
# 73
# [6, 5, 7, 4, 8, 3, 9]
# 2 3
# 128
# [6, 5, 7, 4, 8, 3, 9, 2]
# 10 9
# 59
# [6, 5, 7, 4, 8, 3, 9, 2, 10]
# 1 2
# 129
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1]
# 11 10
# 36
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11]
# 0 1
# 129
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0]
# 12 11
# 29
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0, 12]
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/Segmentation/segmentation_label_538.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_539.dax
# PolyT image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_539.dax
# DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_539.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_539.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_539_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477'] in 2.189s.
# - Correct illumination for channels: ['477']
# -- Keep channels: ['477'] for corr_illumination.
# - Start illumination correction for channels:['477'].
# -- loading illumination correction profile from file:
# 	 477 illumination_correction_477_2304x2304.npy
# -- corrected illumination for channel 477 in 1.128s.
# - Finished illumination correction in 1.144s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_539.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_539_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477', '405'] in 0.331s.
# - Correct illumination for channels: ['405']
# -- Keep channels: ['405'] for corr_illumination.
# - Start illumination correction for channels:['405'].
# -- loading illumination correction profile from file:
# 	 405 illumination_correction_405_2304x2304.npy
# -- corrected illumination for channel 405 in 0.933s.
# - Finished illumination correction in 0.943s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0. 0. 0.] in 0.508s.
# -- drift 1: [0. 0. 0.] in 0.533s.
# -- drift 2: [0. 0. 0.] in 0.537s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Warp drift and chromatic already finished, skip.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_539.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_539_processed.hdf5
# -- all used channels: ['748', '637', '477']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.775s.
# - Correct illumination for channels: ['637']
# -- Keep channels: ['637'] for corr_illumination.
# - Start illumination correction for channels:['637'].
# -- loading illumination correction profile from file:
# 	 637 illumination_correction_637_2304x2304.npy
# -- corrected illumination for channel 637 in 0.937s.
# - Finished illumination correction in 0.948s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.01  2.56  4.97] in 0.505s.
# -- drift 1: [0.   2.53 4.61] in 0.540s.
# -- drift 2: [0.   2.6  5.07] in 0.537s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 10.221s.
# - Finished warp correction in 10.221s.
# - apply microscope corrections
# - run Cellpose segmentation in 40.872s.
# 5 6
# 122
# [6, 5]
# 7 6
# 113
# [6, 5, 7]
# 4 5
# 124
# [6, 5, 7, 4]
# 8 7
# 107
# [6, 5, 7, 4, 8]
# 3 4
# 119
# [6, 5, 7, 4, 8, 3]
# 9 8
# 92
# [6, 5, 7, 4, 8, 3, 9]
# 2 3
# 116
# [6, 5, 7, 4, 8, 3, 9, 2]
# 10 9
# 84
# [6, 5, 7, 4, 8, 3, 9, 2, 10]
# 1 2
# 115
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1]
# 11 10
# 80
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11]
# 0 1
# 109
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0]
# 12 11
# 75
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0, 12]
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/Segmentation/segmentation_label_539.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_540.dax
# PolyT image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_540.dax
# DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_540.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_540.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_540_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477'] in 2.269s.
# - Correct illumination for channels: ['477']
# -- Keep channels: ['477'] for corr_illumination.
# - Start illumination correction for channels:['477'].
# -- loading illumination correction profile from file:
# 	 477 illumination_correction_477_2304x2304.npy
# -- corrected illumination for channel 477 in 1.130s.
# - Finished illumination correction in 1.148s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_540.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_540_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477', '405'] in 0.331s.
# - Correct illumination for channels: ['405']
# -- Keep channels: ['405'] for corr_illumination.
# - Start illumination correction for channels:['405'].
# -- loading illumination correction profile from file:
# 	 405 illumination_correction_405_2304x2304.npy
# -- corrected illumination for channel 405 in 0.934s.
# - Finished illumination correction in 0.944s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0. 0. 0.] in 0.467s.
# -- drift 1: [0. 0. 0.] in 0.502s.
# -- drift 2: [0. 0. 0.] in 0.504s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Warp drift and chromatic already finished, skip.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_540.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_540_processed.hdf5
# -- all used channels: ['748', '637', '477']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.824s.
# - Correct illumination for channels: ['637']
# -- Keep channels: ['637'] for corr_illumination.
# - Start illumination correction for channels:['637'].
# -- loading illumination correction profile from file:
# 	 637 illumination_correction_637_2304x2304.npy
# -- corrected illumination for channel 637 in 0.951s.
# - Finished illumination correction in 0.966s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.   2.49 6.89] in 0.467s.
# -- drift 1: [0.03 2.36 6.74] in 0.502s.
# -- drift 2: [0.01 2.77 6.78] in 0.503s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 10.320s.
# - Finished warp correction in 10.321s.
# - apply microscope corrections
# - run Cellpose segmentation in 40.029s.
# 5 6
# 104
# [6, 5]
# 7 6
# 97
# [6, 5, 7]
# 4 5
# 108
# [6, 5, 7, 4]
# 8 7
# 94
# [6, 5, 7, 4, 8]
# 3 4
# 106
# [6, 5, 7, 4, 8, 3]
# 9 8
# 90
# [6, 5, 7, 4, 8, 3, 9]
# 2 3
# 103
# [6, 5, 7, 4, 8, 3, 9, 2]
# 10 9
# 93
# [6, 5, 7, 4, 8, 3, 9, 2, 10]
# 1 2
# 103
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1]
# 11 10
# 85
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11]
# 0 1
# 98
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0]
# 12 11
# 81
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0, 12]
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/Segmentation/segmentation_label_540.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_541.dax
# PolyT image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_541.dax
# DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_541.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_541.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_541_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477'] in 2.163s.
# - Correct illumination for channels: ['477']
# -- Keep channels: ['477'] for corr_illumination.
# - Start illumination correction for channels:['477'].
# -- loading illumination correction profile from file:
# 	 477 illumination_correction_477_2304x2304.npy
# -- corrected illumination for channel 477 in 1.129s.
# - Finished illumination correction in 1.145s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_541.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_541_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477', '405'] in 0.328s.
# - Correct illumination for channels: ['405']
# -- Keep channels: ['405'] for corr_illumination.
# - Start illumination correction for channels:['405'].
# -- loading illumination correction profile from file:
# 	 405 illumination_correction_405_2304x2304.npy
# -- corrected illumination for channel 405 in 0.926s.
# - Finished illumination correction in 0.936s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0. 0. 0.] in 0.468s.
# -- drift 1: [0. 0. 0.] in 0.498s.
# -- drift 2: [0. 0. 0.] in 0.496s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Warp drift and chromatic already finished, skip.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_541.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_541_processed.hdf5
# -- all used channels: ['748', '637', '477']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.764s.
# - Correct illumination for channels: ['637']
# -- Keep channels: ['637'] for corr_illumination.
# - Start illumination correction for channels:['637'].
# -- loading illumination correction profile from file:
# 	 637 illumination_correction_637_2304x2304.npy
# -- corrected illumination for channel 637 in 0.932s.
# - Finished illumination correction in 0.943s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.01  1.6   6.13] in 0.465s.
# -- drift 1: [-0.03  1.44  6.23] in 0.501s.
# -- drift 2: [-0.01  1.44  6.09] in 0.503s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 10.236s.
# - Finished warp correction in 10.236s.
# - apply microscope corrections
# - run Cellpose segmentation in 39.701s.
# 5 6
# 107
# [6, 5]
# 7 6
# 101
# [6, 5, 7]
# 4 5
# 109
# [6, 5, 7, 4]
# 8 7
# 99
# [6, 5, 7, 4, 8]
# 3 4
# 109
# [6, 5, 7, 4, 8, 3]
# 9 8
# 89
# [6, 5, 7, 4, 8, 3, 9]
# 2 3
# 109
# [6, 5, 7, 4, 8, 3, 9, 2]
# 10 9
# 76
# [6, 5, 7, 4, 8, 3, 9, 2, 10]
# 1 2
# 113
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1]
# 11 10
# 72
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11]
# 0 1
# 106
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0]
# 12 11
# 65
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0, 12]
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/Segmentation/segmentation_label_541.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_542.dax
# PolyT image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_542.dax
# DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_542.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_542.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_542_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477'] in 2.032s.
# - Correct illumination for channels: ['477']
# -- Keep channels: ['477'] for corr_illumination.
# - Start illumination correction for channels:['477'].
# -- loading illumination correction profile from file:
# 	 477 illumination_correction_477_2304x2304.npy
# -- corrected illumination for channel 477 in 1.138s.
# - Finished illumination correction in 1.154s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_542.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_542_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477', '405'] in 0.334s.
# - Correct illumination for channels: ['405']
# -- Keep channels: ['405'] for corr_illumination.
# - Start illumination correction for channels:['405'].
# -- loading illumination correction profile from file:
# 	 405 illumination_correction_405_2304x2304.npy
# -- corrected illumination for channel 405 in 0.934s.
# - Finished illumination correction in 0.944s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0. 0. 0.] in 0.507s.
# -- drift 1: [0. 0. 0.] in 0.532s.
# -- drift 2: [0. 0. 0.] in 0.536s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Warp drift and chromatic already finished, skip.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_542.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_542_processed.hdf5
# -- all used channels: ['748', '637', '477']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.731s.
# - Correct illumination for channels: ['637']
# -- Keep channels: ['637'] for corr_illumination.
# - Start illumination correction for channels:['637'].
# -- loading illumination correction profile from file:
# 	 637 illumination_correction_637_2304x2304.npy
# -- corrected illumination for channel 637 in 0.927s.
# - Finished illumination correction in 0.937s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.   2.98 5.94] in 0.504s.
# -- drift 1: [0.   2.73 5.77] in 0.534s.
# -- drift 2: [0.   3.25 5.68] in 0.534s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 10.202s.
# - Finished warp correction in 10.202s.
# - apply microscope corrections
# - run Cellpose segmentation in 38.283s.
# 5 6
# 98
# [6, 5]
# 7 6
# 92
# [6, 5, 7]
# 4 5
# 96
# [6, 5, 7, 4]
# 8 7
# 82
# [6, 5, 7, 4, 8]
# 3 4
# 96
# [6, 5, 7, 4, 8, 3]
# 9 8
# 80
# [6, 5, 7, 4, 8, 3, 9]
# 2 3
# 94
# [6, 5, 7, 4, 8, 3, 9, 2]
# 10 9
# 65
# [6, 5, 7, 4, 8, 3, 9, 2, 10]
# 1 2
# 86
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1]
# 11 10
# 57
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11]
# 0 1
# 83
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0]
# 12 11
# 47
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0, 12]
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/Segmentation/segmentation_label_542.npy

# %%
# %matplotlib notebook
imshow_mark_3d([dapi_im, polyt_im, labels3d])
# Out:
# <img src="data:image/png;base64,..." width="399.9999913302337">

# %%
from typing import List, Dict, Tuple
def get_overlapping_objects(segmentationZ0: np.ndarray,
                            segmentationZ1: np.ndarray,
                            n0: int,
                            fraction_threshold0: float=0.2,
                            fraction_threshold1: float=0.2) -> Tuple[np.float64, 
                                              np.float64, np.float64]:
    """compare cell labels in adjacent image masks
    Args:
        segmentationZ0: a 2 dimensional numpy array containing a
            segmentation mask in position Z
        segmentationZ1: a 2 dimensional numpy array containing a
            segmentation mask adjacent to segmentationZ0
        n0: an integer with the index of the object (cell/nuclei)
            to be compared between the provided segmentation masks
    Returns:
        a tuple (n1, f0, f1) containing the label of the cell in Z1
        overlapping n0 (n1), the fraction of n0 overlaping n1 (f0) and
        the fraction of n1 overlapping n0 (f1)
    """

    z1Indexes = np.unique(segmentationZ1[segmentationZ0 == n0])

    z1Indexes = z1Indexes[z1Indexes > 0]

    if z1Indexes.shape[0] > 0:

        # calculate overlap fraction
        n0Area = np.count_nonzero(segmentationZ0 == n0)
        n1Area = np.zeros(len(z1Indexes))
        overlapArea = np.zeros(len(z1Indexes))

        for ii in range(len(z1Indexes)):
            n1 = z1Indexes[ii]
            n1Area[ii] = np.count_nonzero(segmentationZ1 == n1)
            overlapArea[ii] = np.count_nonzero((segmentationZ0 == n0) *
                                               (segmentationZ1 == n1))

        n0OverlapFraction = np.asarray(overlapArea / n0Area)
        n1OverlapFraction = np.asarray(overlapArea / n1Area)
        index = list(range(len(n0OverlapFraction)))

        # select the nuclei that has the highest fraction in n0 and n1
        r1, r2, indexSorted = zip(*sorted(zip(n0OverlapFraction,
                                              n1OverlapFraction,
                                              index),
                                  key=lambda x:x[0]+x[1],
                                  reverse=True))

        if (n0OverlapFraction[indexSorted[0]] > fraction_threshold0 and
                n1OverlapFraction[indexSorted[0]] > fraction_threshold1):
            return (z1Indexes[indexSorted[0]],
                    n0OverlapFraction[indexSorted[0]],
                    n1OverlapFraction[indexSorted[0]])
        else:
            return (False, False, False)
    else:
        return (False, False, False)

def combine_2d_segmentation_masks_into_3d(segmentationOutput: np.ndarray,
                                          minKept_zLen:int=2,
                                          matching_overlapRatio:float=0.33,
                                          ) -> np.ndarray:
    """Take a 3 dimensional segmentation masks and relabel them so that
    nuclei in adjacent sections have the same label if the area their
    overlap surpases certain threshold
    Args:
        segmentationOutput: a 3 dimensional numpy array containing the
            segmentation masks arranged as (z, x, y).
        minKept_zLen: minimum z-length of kept segmentation masks
        matching_overlapRatio: miminum overlap ratio bewteen two segmentation masks to be merged.
    Returns:
        ndarray containing a 3 dimensional mask arranged as (z, x, y) of
            relabeled segmented cells
    """

    # Initialize empty array with size as segmentationOutput array
    segmentationCombinedZ = np.zeros(segmentationOutput.shape, dtype=segmentationOutput.dtype)

    # copy the mask of the section farthest to the coverslip to start
    segmentationCombinedZ[-1, :, :] = segmentationOutput[-1, :, :]
    
    # Edit by Pu Zheng: start the seed at the middle z-plane, because usually that is the focal plane:
    mid_z = int(segmentationCombinedZ.shape[0]/2)
    # get the mid plane:
    # copy the mask of the section farthest to the coverslip to start
    segmentationCombinedZ[mid_z, :, :] = segmentationOutput[mid_z, :, :]
    zs = np.arange(0, segmentationCombinedZ.shape[0])
    zs_2_ref = np.abs(zs - (mid_z- 0.01)) # a trick to make mid-z closest to ref
    zs_sorted = zs[np.argsort(zs_2_ref)]
    processed_zs = [mid_z]
    for _iz, _z in enumerate(zs_sorted):
        if _iz == 0:
            continue
        # get ref_z
        _ref_z = processed_zs[np.argmin(np.abs(np.array(processed_zs)-_z))]#zs_sorted[_iz - 1]
        #
        # get non-background cell indexes for plane Z
        zIndex = np.unique(segmentationOutput[_z, :, :])[
                           np.unique(segmentationOutput[_z, :, :]) > 0]
        # attach _z to _ref_z
        # get non-background cell indexes for plane Z-1
        refzIndex = np.unique(segmentationCombinedZ[_ref_z, :, :])[
                              np.unique(segmentationCombinedZ[_ref_z, :, :]) > 0]
        # record assigned index
        assigned_refzIndex = []
        print(_z, _ref_z)
        print(len(zIndex))
        # compare each cell in z0
        for n0 in refzIndex:
            n1, f0, f1 = get_overlapping_objects(segmentationCombinedZ[_ref_z, :, :],
                                                 segmentationOutput[_z, :, :],
                                                 n0, 
                                                 fraction_threshold0=matching_overlapRatio,
                                                 fraction_threshold1=matching_overlapRatio,)
            # If matched: merge
            if n1:
                segmentationCombinedZ[_z, :, :][
                    (segmentationOutput[_z, :, :] == n1)] = n0
                assigned_refzIndex.append(n1)
            # If not matched: copy next layer
            else:
                segmentationCombinedZ[_z, :, :][
                    (segmentationCombinedZ[_ref_z, :, :] == n0)] = n0
                #assigned_refzIndex.append(n1)
                
        # keep the un-assigned indices in the Z-1 plane
        unassigned_refzIndex = [i for i in refzIndex if i not in assigned_refzIndex]
        max_current_id = np.max(segmentationCombinedZ[_z:, :, :])
        for i in range(len(unassigned_refzIndex)):
            unassigned_id = unassigned_refzIndex[i]
            segmentationCombinedZ[_z, :, :][
                    (segmentationOutput[_z, :, :] == unassigned_id)] = max_current_id + 1 +i
        
        processed_zs.append(_z)
        print(processed_zs)
        
    # remove label with only 1 z-layer
    segmentationCleanedZ = np.zeros(segmentationOutput.shape, dtype=np.int16)
    for _lb in np.arange(1, np.max(segmentationCombinedZ)+1):
        _cellMask = (segmentationCombinedZ==_lb)
        _cell_zIndex = np.where(_cellMask.any((1,2)))[0]
        #print(_cell_zIndex)
        if len(_cell_zIndex) < minKept_zLen:
            continue
        else:
            segmentationCleanedZ[segmentationCombinedZ==_lb] = np.max(segmentationCleanedZ) + 1
                
            
            
    return segmentationCleanedZ

# %%
merged_labels3d = combine_2d_segmentation_masks_into_3d(labels3d)
# Out:
# 5 6
# 105
# [6, 5]
# 7 6
# 98
# [6, 5, 7]
# 4 5
# 105
# [6, 5, 7, 4]
# 8 7
# 90
# [6, 5, 7, 4, 8]
# 3 4
# 105
# [6, 5, 7, 4, 8, 3]
# 9 8
# 85
# [6, 5, 7, 4, 8, 3, 9]
# 2 3
# 100
# [6, 5, 7, 4, 8, 3, 9, 2]
# 10 9
# 76
# [6, 5, 7, 4, 8, 3, 9, 2, 10]
# 1 2
# 93
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1]
# 11 10
# 66
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11]
# 0 1
# 81
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0]
# 12 11
# 64
# [6, 5, 7, 4, 8, 3, 9, 2, 10, 1, 11, 0, 12]

# %%
from merlin.analysis.segment import CellPoseSegment

# %%
# %%time
combined_labels_3d = CellPoseSegment.combine_2d_segmentation_masks_into_3d(labels3d)
# Out:
# CPU times: user 32 s, sys: 275 ms, total: 32.3 s
# Wall time: 32.2 s

# %%
imshow_mark_3d([dapi_im, polyt_im, labels3d, corr_labels3d, merged_labels3d])
# Out:
# <img src="data:image/png;base64,..." width="399.9999913302337">

# %%
imshow_mark_3d([_dapi_im, _polyt_im, labels3d, combined_labels_3d])

# %%
# %matplotlib notebook
imshow_mark_3d([polyt_im, dapi_im, corr_labels3d])
# Out:
# <img src="data:image/png;base64,..." width="399.999976880624">

# %% [markdown]
# # STEP2: Watershed: Optional, potentially make it worse

# %%
watershed_th = 1.6
ref_idx = 0

for _fov_id, _fov_name in enumerate(fovs):
    

    _save_id = _fov_id 
    
    seg_save_file = os.path.join(segmentation_save_folder, f'segmentation_label_{_save_id}.npy')
    watershed_save_file = os.path.join(watershed_folder, f'segmentation_label_{_save_id}.npy')
    if os.path.exists(watershed_save_file):
        print(f"{watershed_save_file} already exists, skip")
        continue
    # Load segmentation
    if os.path.isfile(seg_save_file):
        print(f"- directly load seg from: {seg_save_file}")
        corr_labels3d = np.load(seg_save_file)
    else:
        print(f"- seg file: {seg_save_file} has not been generated yet, skip. ")
        continue
        
    # find images
    ref_image_file = os.path.join(data_folder, color_usage_df.index[ref_idx], _fov_name)
    dapi_image_file = os.path.join(data_folder, dapi_info['hyb'], _fov_name)
    polyt_image_file = os.path.join(data_folder, polyt_info['hyb'], _fov_name)
    print(f"reference image: {ref_image_file}")
    print(f"PolyT image: {polyt_image_file}")
    print(f"DAPI image: {dapi_image_file}")
    # load reference DAPI
    _ref_cls = DaxProcesser(ref_image_file, CorrectionFolder=correction_folder, 
                            FiducialChannel=fiducial_channel, DapiChannel=dapi_info['channel'])
    _ref_cls._load_image(sel_channels=[fiducial_channel])
    _ref_cls._corr_illumination(correction_channels=[fiducial_channel])
    _ref_im = getattr(_ref_cls, f'im_{fiducial_channel}')

    # load dapi
    _dapi_cls = DaxProcesser(dapi_image_file, CorrectionFolder=correction_folder, 
                        FiducialChannel=fiducial_channel)
    _dapi_cls._load_image(sel_channels=[dapi_info['channel'],fiducial_channel])
    _dapi_cls.ref_correction_channel = '637'
    _dapi_cls._corr_illumination(correction_channels=[dapi_info['channel']])
    _dapi_cls._calculate_drift(_ref_im, )
    _dapi_cls._corr_warpping_drift_chromatic(correction_channels=[dapi_info['channel']], corr_chromatic=False) # removed 405 to increase efficiency
    _dapi_im = getattr(_dapi_cls, f"im_{dapi_info['channel']}")

    # load polyT
    _polyt_cls = DaxProcesser(polyt_image_file, CorrectionFolder=correction_folder, 
                        FiducialChannel=fiducial_channel)
    _polyt_cls._load_image(sel_channels=[polyt_info['channel'],fiducial_channel])
    _polyt_cls.ref_correction_channel = '637'
    _polyt_cls._corr_illumination(correction_channels=[polyt_info['channel']])
    _polyt_cls._calculate_drift(_ref_im, )
    _polyt_cls._corr_warpping_drift_chromatic(correction_channels=[polyt_info['channel']], corr_chromatic=False) # removed 405 to increase efficiency
    _polyt_im = getattr(_polyt_cls, f"im_{polyt_info['channel']}")
    
    
    _save_id = _fov_id 

    dapi_im = Align_Segmentation._correct_image3D_by_microscope_param(_dapi_im, microscope_params)
    polyt_im = Align_Segmentation._correct_image3D_by_microscope_param(_polyt_im, microscope_params)

    # Prepare watershed
    print(f"- run watershed", end=' ')
    _watershed_start = time.time()
    water_input_im = polyt_im
    waterIm, waterMask = watershed.prepare_watershed_images(water_input_im, watershed_th)
    waterMask[corr_labels3d > 0] = True
    waterMask = ndimage.binary_dilation(waterMask, structure=morphology.ball(1))
    # watershed
    new_labels = segmentation.watershed(
                    waterIm, corr_labels3d, mask=waterMask,
                    connectivity=np.ones((3, 3, 3)), watershed_line=True)
    print(f"in {time.time()-_watershed_start:.3f}s.")

    # save
    # save this segmentation mask
    print(f"- save to file: {watershed_save_file}")
    np.save(watershed_save_file.split('.npy')[0], new_labels, )
    
    break
# Out:
# - directly load seg from: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/Segmentation/segmentation_label_0.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_000.dax
# PolyT image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_000.dax
# DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_000.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_000.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_000_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477'] in 0.398s.
# - Correct illumination for channels: ['477']
# -- Keep channels: ['477'] for corr_illumination.
# - Start illumination correction for channels:['477'].
# -- loading illumination correction profile from file:
# 	 477 illumination_correction_477_2304x2304.npy
# -- corrected illumination for channel 477 in 1.587s.
# - Finished illumination correction in 1.613s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_000.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H0M1/Conv_zscan_000_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['477', '405'] in 0.411s.
# - Correct illumination for channels: ['405']
# -- Keep channels: ['405'] for corr_illumination.
# - Start illumination correction for channels:['405'].
# -- loading illumination correction profile from file:
# 	 405 illumination_correction_405_2304x2304.npy
# -- corrected illumination for channel 405 in 1.739s.
# - Finished illumination correction in 1.762s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0. 0. 0.] in 0.776s.
# -- drift 1: [0. 0. 0.] in 0.822s.
# -- drift 2: [0. 0. 0.] in 0.731s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Warp drift and chromatic already finished, skip.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_000.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/H8M9/Conv_zscan_000_processed.hdf5
# -- all used channels: ['748', '637', '477']
# -- single image size: [  13 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.690s.
# - Correct illumination for channels: ['637']
# -- Keep channels: ['637'] for corr_illumination.
# - Start illumination correction for channels:['637'].
# -- loading illumination correction profile from file:
# 	 637 illumination_correction_637_2304x2304.npy
# -- corrected illumination for channel 637 in 3.219s.
# - Finished illumination correction in 3.418s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [ 0.   -9.92  5.22] in 0.741s.
# -- drift 1: [-0.02 -9.54  5.83] in 0.753s.
# -- drift 2: [-0.01 -9.61  5.37] in 0.747s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 18.616s.
# - Finished warp correction in 18.616s.
# - run watershed in 167.596s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20231222-4T1tumor_F170_MF4/Segmentation/watershed/segmentation_label_0.npy

# %%
# %matplotlib notebook
imshow_mark_3d([new_labels, corr_labels3d])
# Out:
# <img src="data:image/png;base64,..." width="400">

# %% [markdown]
# ## visualize merlin_output_tif

# %%
import tifffile
ims = tifffile.imread(r'Z:\MERFISH_analysis\20230513-wtBrain_MO4\FiducialCorrelationWarp\images\aligned_fiducial_images30.tif')
