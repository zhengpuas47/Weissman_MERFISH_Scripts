# %%
#import torch
import os, sys, re, time
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
#import torch
print(os.getpid())
sys.path.append(r"/lab/weissman_imaging/puzheng/Softwares")
# Out:
# 1060678

# %%
import cv2
from ChromAn.src.file_io.data_organization import search_fovs_in_folders, Color_Usage
from ChromAn.src.segmentation_tools.cells import Align_Segmentation

# %%
import merlin
from merlin.util import watershed
from scipy import ndimage
from skimage import morphology
from skimage import segmentation
from copy import copy

# %%
# Cellpose 
from cellpose import models

# %% [markdown]
# ## Folders

# %%
# data_folder
data_folder = r'/lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5'
# correction
correction_folder = r'/lab/weissman_imaging/puzheng/Corrections/20240401-Merscope01_s11_n1200'

segmentation_save_folder = os.path.join(data_folder, 'Segmentation')
if not os.path.exists(segmentation_save_folder):
    print(segmentation_save_folder)
    os.makedirs(segmentation_save_folder)
watershed_folder = os.path.join(segmentation_save_folder, 'watershed')
if not os.path.exists(watershed_folder):
    print(watershed_folder)
    os.makedirs(watershed_folder)
# Out:
# /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation
# /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/watershed

# %%
# transpose with microscope
parameter_folder = r'/lab/weissman_imaging/puzheng/Softwares/Weissman_MERFISH_Scripts/merlin_parameters'
microscope_file = os.path.join(parameter_folder, 'microscope', 'merscope01_microscope.json')
microscope_params = Align_Segmentation._read_microscope_json(microscope_file)
microscope_params
# Out:
# {'flip_horizontal': False,
#  'flip_vertical': True,
#  'transpose': True,
#  'microns_per_pixel': 0.107,
#  'image_dimensions': [2304, 2304]}

# %%
# search folders
folders, fovs = search_fovs_in_folders(data_folder)
# Color usage file marks the organization of imaging files
color_usage_filename = os.path.join(data_folder, 'Analysis', 'color_usage_MF5_v2.csv')
color_usage_df = Color_Usage(color_usage_filename)
# Out:
# - searching in folder: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5
# -- 12 folders, 813 fovs detected.
# - load color_usage from file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Analysis/color_usage_MF5_v2.csv

# %%
# from color_usage, find dapi / polyt / fiducial
dapi_info = color_usage_df.get_dapi_info()[0]
polyt_info = color_usage_df.get_polyt_info()[0]
fiducial_channel = color_usage_df.get_fiducial_channel(color_usage_df)
print(dapi_info, polyt_info, fiducial_channel)
# Out:
# {'hyb': 'H0M1', 'channel': '405'} {'channel': '637', 'hyb': 'H11M12'} 477

# %% [markdown]
# # Run segmentation

# %%
from ChromAn.src.file_io.dax_process import DaxProcesser
from ChromAn.src.visual_tools.interactive import imshow_mark_3d
from merlin.analysis.segment import CellPoseSegment

# %%
from importlib import reload

# %%
import ChromAn
reload(ChromAn.src.file_io.dax_process)
# Out:
# <module 'ChromAn.src.file_io.dax_process' from '/lab/weissman_imaging/puzheng/Softwares/ChromAn/src/file_io/dax_process.py'>

# %%
for _fov_id, _fov_name in enumerate(fovs):

    _save_id = _fov_id 
    seg_save_file = os.path.join(segmentation_save_folder, f'segmentation_label_{_save_id}.npy')
    if os.path.exists(seg_save_file):
        print(f"Segmentation label file: {seg_save_file} already exists, skip")
        continue
    
    ref_image_file = os.path.join(data_folder, dapi_info['hyb'], _fov_name)
    polyt_image_file = os.path.join(data_folder, polyt_info['hyb'], _fov_name)
    print(f"reference image: {ref_image_file}")
    print(f"PolyT and DAPI image: {polyt_image_file}")
    # load reference DAPI
    _ref_cls = DaxProcesser(ref_image_file, CorrectionFolder=correction_folder, 
                            FiducialChannel=fiducial_channel, DapiChannel=dapi_info['channel'])
    _ref_cls._load_image(sel_channels=[fiducial_channel,dapi_info['channel']])
    #_ref_cls._corr_illumination()
    _ref_im = getattr(_ref_cls, f'im_{fiducial_channel}')
    
    # load polyT and DAPI
    _cls = DaxProcesser(polyt_image_file, CorrectionFolder=correction_folder, 
                        FiducialChannel=fiducial_channel)
    _cls._load_image(sel_channels=[polyt_info['channel'],fiducial_channel])
    _cls.ref_correction_channel = '637'
    #_cls._corr_illumination()
    _cls._calculate_drift(_ref_im, )
    _cls._corr_warpping_drift_chromatic(correction_channels=[polyt_info['channel']], corr_chromatic=False) # removed 405 to increase efficiency
    
    _dapi_im = getattr(_ref_cls, f"im_{dapi_info['channel']}")
    _polyt_im = getattr(_cls, f"im_{polyt_info['channel']}")
    # Run segmentation if target file not exist:
    if os.path.isfile(seg_save_file):
        print(f"- directly load seg from: {seg_save_file}")
        corr_labels3d = np.load(seg_save_file)
    else:
        print(f"- apply microscope corrections")
        dapi_im = Align_Segmentation._correct_image3D_by_microscope_param(_dapi_im, microscope_params)
        polyt_im = Align_Segmentation._correct_image3D_by_microscope_param(_polyt_im, microscope_params)

        # Create cellpose model
        print(f"- run Cellpose segmentation", end=' ')
        _cellpose_start = time.time()
        seg_model = models.CellposeModel(gpu=True, model_type='TN2')
        # Run cellpose prediction
        labels3d, _, _ = seg_model.eval(np.stack([polyt_im, dapi_im], axis=3), 
                                        #batch_size=60, #anisotropy=250/108,
                                        anisotropy=1200/108,
                                        cellprob_threshold=0, 
                                        channels=[1,2], 
                                        diameter=50, 
                                        min_size=2000,
                                        do_3D=False,
                                        )
        print(f"in {time.time()-_cellpose_start:.3f}s.")

        # convert to corrected labels
        corr_labels3d = CellPoseSegment.combine_2d_segmentation_masks_into_3d(labels3d)

        # save this segmentation mask
        print(f"- save to {np.max(corr_labels3d)} labels to file: {seg_save_file}")
        np.save(seg_save_file.split('.npy')[0], corr_labels3d, )
# Out:
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_0.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_1.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_2.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_3.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_4.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_5.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_6.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_7.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_8.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_9.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_10.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_11.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_12.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_13.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_14.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_15.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_16.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_17.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_18.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_19.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_20.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_21.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_22.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_23.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_24.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_25.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_26.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_27.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_28.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_29.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_30.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_31.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_32.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_33.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_34.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_35.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_36.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_37.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_38.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_39.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_40.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_41.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_42.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_43.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_44.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_45.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_46.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_47.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_48.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_49.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_50.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_51.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_52.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_53.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_54.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_55.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_56.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_57.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_58.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_59.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_60.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_61.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_62.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_63.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_64.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_65.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_66.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_67.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_68.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_69.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_70.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_71.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_72.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_73.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_74.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_75.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_76.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_77.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_78.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_79.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_80.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_81.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_82.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_83.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_84.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_85.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_86.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_87.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_88.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_89.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_90.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_91.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_92.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_93.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_94.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_95.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_96.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_97.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_98.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_99.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_100.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_101.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_102.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_103.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_104.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_105.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_106.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_107.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_108.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_109.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_110.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_111.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_112.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_113.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_114.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_115.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_116.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_117.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_118.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_119.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_120.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_121.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_122.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_123.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_124.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_125.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_126.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_127.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_128.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_129.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_130.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_131.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_132.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_133.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_134.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_135.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_136.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_137.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_138.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_139.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_140.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_141.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_142.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_143.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_144.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_145.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_146.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_147.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_148.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_149.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_150.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_151.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_152.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_153.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_154.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_155.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_156.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_157.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_158.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_159.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_160.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_161.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_162.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_163.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_164.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_165.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_166.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_167.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_168.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_169.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_170.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_171.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_172.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_173.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_174.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_175.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_176.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_177.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_178.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_179.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_180.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_181.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_182.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_183.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_184.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_185.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_186.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_187.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_188.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_189.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_190.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_191.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_192.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_193.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_194.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_195.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_196.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_197.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_198.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_199.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_200.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_201.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_202.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_203.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_204.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_205.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_206.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_207.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_208.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_209.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_210.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_211.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_212.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_213.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_214.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_215.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_216.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_217.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_218.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_219.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_220.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_221.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_222.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_223.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_224.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_225.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_226.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_227.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_228.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_229.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_230.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_231.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_232.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_233.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_234.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_235.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_236.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_237.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_238.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_239.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_240.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_241.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_242.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_243.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_244.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_245.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_246.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_247.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_248.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_249.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_250.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_251.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_252.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_253.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_254.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_255.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_256.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_257.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_258.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_259.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_260.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_261.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_262.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_263.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_264.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_265.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_266.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_267.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_268.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_269.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_270.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_271.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_272.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_273.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_274.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_275.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_276.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_277.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_278.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_279.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_280.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_281.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_282.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_283.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_284.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_285.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_286.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_287.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_288.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_289.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_290.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_291.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_292.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_293.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_294.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_295.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_296.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_297.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_298.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_299.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_300.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_301.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_302.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_303.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_304.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_305.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_306.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_307.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_308.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_309.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_310.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_311.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_312.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_313.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_314.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_315.npy already exists, skip
# ...
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_708.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_709.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_710.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_711.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_712.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_713.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_714.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_715.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_716.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_717.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_718.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_719.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_720.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_721.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_722.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_723.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_724.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_725.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_726.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_727.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_728.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_729.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_730.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_731.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_732.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_733.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_734.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_735.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_736.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_737.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_738.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_739.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_740.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_741.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_742.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_743.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_744.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_745.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_746.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_747.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_748.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_749.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_750.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_751.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_752.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_753.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_754.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_755.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_756.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_757.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_758.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_759.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_760.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_761.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_762.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_763.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_764.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_765.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_766.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_767.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_768.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_769.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_770.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_771.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_772.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_773.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_774.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_775.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_776.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_777.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_778.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_779.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_780.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_781.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_782.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_783.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_784.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_785.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_786.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_787.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_788.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_789.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_790.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_791.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_792.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_793.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_794.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_795.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_796.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_797.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_798.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_799.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_800.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_801.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_802.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_803.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_804.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_805.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_806.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_807.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_808.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_809.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_810.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_811.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/msBrain/20240417-untreatedBrain_MF5/Segmentation/segmentation_label_812.npy already exists, skip

# %%
# %matplotlib notebook
imshow_mark_3d([_dapi_im, _polyt_im, labels3d, corr_labels3d])
# Out:
# <div id='162b967b-e5c9-4bba-be8f-fb85edc19548'></div>

# %% [markdown]
# # STEP2: Watershed: Optional, potentially make it worse

# %%
watershed_th = 1.4

for _fov_id, _fov_name in enumerate(fovs):
    

    _save_id = _fov_id 
    
    seg_save_file = os.path.join(segmentation_save_folder, f'segmentation_label_{_save_id}.npy')
    watershed_save_file = os.path.join(watershed_folder, f'segmentation_label_{_save_id}.npy')
    if os.path.exists(watershed_save_file):
        print(f"{watershed_save_file} already exists, skip")
        continue
    # Load segmentation
    if os.path.isfile(seg_save_file):
        print(f"- directly load seg from: {seg_save_file}")
        corr_labels3d = np.load(seg_save_file)
    else:
        print(f"- seg file: {seg_save_file} has not been generated yet, skip. ")
        continue
        
    ref_image_file = os.path.join(data_folder, dapi_info['hyb'], _fov_name)
    polyt_image_file = os.path.join(data_folder, polyt_info['hyb'], _fov_name)
    print(f"reference image: {ref_image_file}")
    print(f"PolyT and DAPI image: {polyt_image_file}")
    # load reference DAPI
    _ref_cls = DaxProcesser(ref_image_file, CorrectionFolder=correction_folder, 
                            FiducialChannel=fiducial_channel, DapiChannel=dapi_info['channel'])
    _ref_cls._load_image(sel_channels=[fiducial_channel,dapi_info['channel']])
    _ref_cls._corr_illumination()
    _ref_im = getattr(_ref_cls, f'im_{fiducial_channel}')
    
    # load polyT and DAPI
    _cls = DaxProcesser(polyt_image_file, CorrectionFolder=correction_folder, 
                        FiducialChannel=fiducial_channel)
    _cls._load_image(sel_channels=[polyt_info['channel'],fiducial_channel])
    _cls._corr_illumination()
    _cls._calculate_drift(_ref_im)
    _cls._corr_warpping_drift_chromatic(correction_channels=[polyt_info['channel']], corr_chromatic=False) # removed 405 to increase efficiency
    # extract images
    _dapi_im = copy(getattr(_ref_cls, f"im_{dapi_info['channel']}"))
    _polyt_im = copy(getattr(_cls, f"im_{polyt_info['channel']}"))
    
    
    _save_id = _fov_id 

    dapi_im = Align_Segmentation._correct_image3D_by_microscope_param(_dapi_im, microscope_params)
    polyt_im = Align_Segmentation._correct_image3D_by_microscope_param(_polyt_im, microscope_params)

    # Prepare watershed
    print(f"- run watershed", end=' ')
    _watershed_start = time.time()
    water_input_im = polyt_im
    waterIm, waterMask = watershed.prepare_watershed_images(water_input_im, watershed_th)
    waterMask[corr_labels3d > 0] = True
    waterMask = ndimage.binary_dilation(waterMask, structure=morphology.ball(1))
    # watershed
    new_labels = segmentation.watershed(
                    waterIm, corr_labels3d, mask=waterMask,
                    connectivity=np.ones((3, 3, 3)), watershed_line=True)
    print(f"in {time.time()-_watershed_start:.3f}s.")

    # save
    # save this segmentation mask
    print(f"- save to file: {watershed_save_file}")
    np.save(watershed_save_file.split('.npy')[0], new_labels, )
    
    #break
# Out:
# - directly load seg from: /lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/Segmentation/segmentation_label_0.npy
# reference image: /lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H0M1/Conv_zscan_000.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H11M12/Conv_zscan_000.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H0M1/Conv_zscan_000.dax
# - New save file: /lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H0M1/Conv_zscan_000_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 2.293s.
# - Correct illumination for channels: ['477', '405']
# -- Keep channels: ['477', '405'] for corr_illumination.
# - Start illumination correction for channels:['477', '405'].
# -- loading illumination correction profile from file:
# 	 477 illumination_correction_477_2304x2304.npy
# 	 405 illumination_correction_405_2304x2304.npy
# -- corrected illumination for channel 477 in 0.973s.
# -- corrected illumination for channel 405 in 0.823s.
# - Finished illumination correction in 1.827s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H11M12/Conv_zscan_000.dax
# - New save file: /lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H11M12/Conv_zscan_000_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.203s.
# - Correct illumination for channels: ['637', '477']
# -- Keep channels: ['637', '477'] for corr_illumination.
# - Start illumination correction for channels:['637', '477'].
# -- loading illumination correction profile from file:
# 	 637 illumination_correction_637_2304x2304.npy
# 	 477 illumination_correction_477_2304x2304.npy
# -- corrected illumination for channel 637 in 0.891s.
# -- corrected illumination for channel 477 in 0.835s.
# - Finished illumination correction in 1.757s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [ 0.01  5.01 -9.04] in 0.452s.
# -- drift 1: [ 0.01  5.48 -8.73] in 0.461s.
# -- drift 2: [ 0.03  4.8  -8.91] in 0.472s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 9.655s.
# - Finished warp correction in 9.656s.
# - run watershed in 119.089s.
# - save to file: /lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/Segmentation/watershed/segmentation_label_0.npy
# - directly load seg from: /lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/Segmentation/segmentation_label_1.npy
# reference image: /lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H0M1/Conv_zscan_001.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H11M12/Conv_zscan_001.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H0M1/Conv_zscan_001.dax
# - New save file: /lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H0M1/Conv_zscan_001_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 2.028s.
# - Correct illumination for channels: ['477', '405']
# -- Keep channels: ['477', '405'] for corr_illumination.
# - Start illumination correction for channels:['477', '405'].
# -- loading illumination correction profile from file:
# 	 477 illumination_correction_477_2304x2304.npy
# 	 405 illumination_correction_405_2304x2304.npy
# -- corrected illumination for channel 477 in 1.014s.
# -- corrected illumination for channel 405 in 0.812s.
# - Finished illumination correction in 1.859s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H11M12/Conv_zscan_001.dax
# - New save file: /lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H11M12/Conv_zscan_001_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.189s.
# - Correct illumination for channels: ['637', '477']
# -- Keep channels: ['637', '477'] for corr_illumination.
# - Start illumination correction for channels:['637', '477'].
# -- loading illumination correction profile from file:
# 	 637 illumination_correction_637_2304x2304.npy
# 	 477 illumination_correction_477_2304x2304.npy
# -- corrected illumination for channel 637 in 0.956s.
# -- corrected illumination for channel 477 in 0.808s.
# - Finished illumination correction in 1.794s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [ 0.    6.48 -5.53] in 0.437s.
# -- drift 1: [-0.01  7.04 -5.47] in 0.456s.
# -- drift 2: [ 0.01  6.54 -5.49] in 0.457s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.848s.
# - Finished warp correction in 8.848s.
# - run watershed in 150.385s.
# - save to file: /lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/Segmentation/watershed/segmentation_label_1.npy
# - directly load seg from: /lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/Segmentation/segmentation_label_2.npy
# reference image: /lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H0M1/Conv_zscan_002.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H11M12/Conv_zscan_002.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H0M1/Conv_zscan_002.dax
# - New save file: /lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H0M1/Conv_zscan_002_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 2.004s.
# - Correct illumination for channels: ['477', '405']
# -- Keep channels: ['477', '405'] for corr_illumination.
# - Start illumination correction for channels:['477', '405'].
# -- loading illumination correction profile from file:
# 	 477 illumination_correction_477_2304x2304.npy
# 	 405 illumination_correction_405_2304x2304.npy
# -- corrected illumination for channel 477 in 0.796s.
# -- corrected illumination for channel 405 in 0.797s.
# - Finished illumination correction in 1.615s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H11M12/Conv_zscan_002.dax
# - New save file: /lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H11M12/Conv_zscan_002_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.299s.
# - Correct illumination for channels: ['637', '477']
# -- Keep channels: ['637', '477'] for corr_illumination.
# - Start illumination correction for channels:['637', '477'].
# -- loading illumination correction profile from file:
# 	 637 illumination_correction_637_2304x2304.npy
# 	 477 illumination_correction_477_2304x2304.npy
# -- corrected illumination for channel 637 in 0.956s.
# -- corrected illumination for channel 477 in 0.798s.
# - Finished illumination correction in 1.784s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.02  7.47 -6.74] in 0.438s.
# -- drift 1: [ 0.    7.92 -6.97] in 0.456s.
# -- drift 2: [-0.02  8.31 -6.66] in 0.454s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.787s.
# - Finished warp correction in 8.787s.
# - run watershed in 215.291s.
# - save to file: /lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/Segmentation/watershed/segmentation_label_2.npy
# - directly load seg from: /lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/Segmentation/segmentation_label_3.npy
# reference image: /lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H0M1/Conv_zscan_003.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H11M12/Conv_zscan_003.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H0M1/Conv_zscan_003.dax
# - New save file: /lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H0M1/Conv_zscan_003_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 1.878s.
# - Correct illumination for channels: ['477', '405']
# -- Keep channels: ['477', '405'] for corr_illumination.
# - Start illumination correction for channels:['477', '405'].
# -- loading illumination correction profile from file:
# 	 477 illumination_correction_477_2304x2304.npy
# 	 405 illumination_correction_405_2304x2304.npy
# -- corrected illumination for channel 477 in 0.887s.
# -- corrected illumination for channel 405 in 0.788s.
# - Finished illumination correction in 1.708s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H11M12/Conv_zscan_003.dax
# - New save file: /lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H11M12/Conv_zscan_003_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.078s.
# - Correct illumination for channels: ['637', '477']
# -- Keep channels: ['637', '477'] for corr_illumination.
# - Start illumination correction for channels:['637', '477'].
# -- loading illumination correction profile from file:
# 	 637 illumination_correction_637_2304x2304.npy
# 	 477 illumination_correction_477_2304x2304.npy
# -- corrected illumination for channel 637 in 0.950s.
# -- corrected illumination for channel 477 in 0.791s.
# - Finished illumination correction in 1.771s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.02  7.89 -6.8 ] in 0.440s.
# -- drift 1: [ 0.    8.48 -6.89] in 0.460s.
# -- drift 2: [ 0.    9.29 -6.2 ] in 0.454s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.659s.
# - Finished warp correction in 8.659s.
# - run watershed in 200.466s.
# - save to file: /lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/Segmentation/watershed/segmentation_label_3.npy
# - directly load seg from: /lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/Segmentation/segmentation_label_4.npy
# reference image: /lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H0M1/Conv_zscan_004.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H11M12/Conv_zscan_004.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H0M1/Conv_zscan_004.dax
# - New save file: /lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H0M1/Conv_zscan_004_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 2.035s.
# - Correct illumination for channels: ['477', '405']
# -- Keep channels: ['477', '405'] for corr_illumination.
# - Start illumination correction for channels:['477', '405'].
# -- loading illumination correction profile from file:
# 	 477 illumination_correction_477_2304x2304.npy
# 	 405 illumination_correction_405_2304x2304.npy
# -- corrected illumination for channel 477 in 0.945s.
# -- corrected illumination for channel 405 in 0.784s.
# - Finished illumination correction in 1.762s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H11M12/Conv_zscan_004.dax
# - New save file: /lab/weissman_imaging/puzheng/msBrain/20240414-EAEbrain_MF5/H11M12/Conv_zscan_004_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.072s.
# - Correct illumination for channels: ['637', '477']
# -- Keep channels: ['637', '477'] for corr_illumination.
# - Start illumination correction for channels:['637', '477'].
# -- loading illumination correction profile from file:
# 	 637 illumination_correction_637_2304x2304.npy
# 	 477 illumination_correction_477_2304x2304.npy
# -- corrected illumination for channel 637 in 0.957s.

# %%
imshow_mark_3d([new_labels, corr_labels3d])
# Out:
# <img src="data:image/png;base64,..." width="399.9999913302337">

# %% [markdown]
# # Copy segmentation labels

# %%
# Copy segmentation labels
from shutil import copyfile
data_master_folder = r'/lab/weissman_imaging/puzheng/MERFISH_data'
analysis_master_folder = r'/lab/weissman_imaging/puzheng/MERFISH_analysis'
print(os.listdir(data_master_folder))
experiment_date = os.path.basename(data_folder).split('-')[0]
print(experiment_date)
for _fd in os.listdir(data_master_folder):
    if experiment_date in _fd:
        break
analysis_folder = os.path.join(analysis_master_folder, _fd)
print(analysis_folder)
# Out:
# ['20240404-untreatedCord_MF5', '.DS_Store']
# 20240404
# /lab/weissman_imaging/puzheng/MERFISH_analysis/20240404-untreatedCord_MF5

# %%
segmentation_target_folder = os.path.join(analysis_folder, 'CellPoseSegment', 'segmentation_label')
print(segmentation_target_folder)
if not os.path.exists(segmentation_target_folder):
    os.makedirs(segmentation_target_folder)
# copy
seg_label_filenames = [os.path.join(watershed_folder, _f) 
                       for _f in os.listdir(watershed_folder) 
                       if 'segmentation_label' in _f and '.npy' in _f]

for _f in seg_label_filenames:
    print(os.path.basename(_f))
    copyfile(_f, os.path.join(segmentation_target_folder, os.path.basename(_f)))
# Out:
# /lab/weissman_imaging/puzheng/MERFISH_analysis/20240404-untreatedCord_MF5/CellPoseSegment/segmentation_label
# segmentation_label_0.npy
# segmentation_label_1.npy
# segmentation_label_2.npy
# segmentation_label_3.npy
# segmentation_label_4.npy
# segmentation_label_5.npy
# segmentation_label_6.npy
# segmentation_label_7.npy
# segmentation_label_8.npy
# segmentation_label_9.npy
# segmentation_label_10.npy
# segmentation_label_11.npy
# segmentation_label_12.npy
# segmentation_label_13.npy
# segmentation_label_14.npy
# segmentation_label_15.npy
# segmentation_label_16.npy
# segmentation_label_17.npy
# segmentation_label_18.npy
# segmentation_label_19.npy
# segmentation_label_20.npy
# segmentation_label_21.npy
# segmentation_label_22.npy
# segmentation_label_23.npy
# segmentation_label_24.npy
# segmentation_label_25.npy
# segmentation_label_26.npy
# segmentation_label_27.npy
# segmentation_label_28.npy
# segmentation_label_29.npy
# segmentation_label_30.npy
# segmentation_label_31.npy
# segmentation_label_32.npy
# segmentation_label_33.npy
# segmentation_label_34.npy
# segmentation_label_35.npy
# segmentation_label_36.npy
# segmentation_label_37.npy
# segmentation_label_38.npy
# segmentation_label_39.npy
# segmentation_label_40.npy
# segmentation_label_41.npy
# segmentation_label_42.npy
# segmentation_label_43.npy
# segmentation_label_44.npy
# segmentation_label_45.npy
# segmentation_label_46.npy
# segmentation_label_47.npy
# segmentation_label_48.npy
# segmentation_label_49.npy
# segmentation_label_50.npy
# segmentation_label_51.npy
# segmentation_label_52.npy
# segmentation_label_53.npy
# segmentation_label_54.npy
# segmentation_label_55.npy
# segmentation_label_56.npy
# segmentation_label_57.npy
# segmentation_label_58.npy
# segmentation_label_59.npy
# segmentation_label_60.npy
# segmentation_label_61.npy
# segmentation_label_62.npy
# segmentation_label_63.npy
# segmentation_label_64.npy
# segmentation_label_65.npy
# segmentation_label_66.npy
# segmentation_label_67.npy
# segmentation_label_68.npy
# segmentation_label_69.npy
# segmentation_label_70.npy
# segmentation_label_71.npy
# segmentation_label_72.npy
# segmentation_label_73.npy
# segmentation_label_74.npy
# segmentation_label_75.npy
# segmentation_label_76.npy
# segmentation_label_77.npy
# segmentation_label_78.npy
# segmentation_label_79.npy
# segmentation_label_80.npy
# segmentation_label_81.npy
# segmentation_label_82.npy
# segmentation_label_83.npy
# segmentation_label_84.npy
# segmentation_label_85.npy
# segmentation_label_86.npy
# segmentation_label_87.npy
# segmentation_label_88.npy
# segmentation_label_89.npy
# segmentation_label_90.npy
# segmentation_label_91.npy
# segmentation_label_92.npy
# segmentation_label_93.npy
# segmentation_label_94.npy
# segmentation_label_95.npy
# segmentation_label_96.npy
# segmentation_label_97.npy
# segmentation_label_98.npy
# segmentation_label_99.npy
# segmentation_label_100.npy
# segmentation_label_101.npy
# segmentation_label_102.npy
# segmentation_label_103.npy
# segmentation_label_104.npy
# segmentation_label_105.npy
# segmentation_label_106.npy
# segmentation_label_107.npy
# segmentation_label_108.npy
# segmentation_label_109.npy
# segmentation_label_110.npy
# segmentation_label_111.npy
# segmentation_label_112.npy
# segmentation_label_113.npy
# segmentation_label_114.npy
# segmentation_label_115.npy
# segmentation_label_116.npy
# segmentation_label_117.npy
# segmentation_label_118.npy
# segmentation_label_119.npy
# segmentation_label_120.npy
# segmentation_label_121.npy
# segmentation_label_122.npy
# segmentation_label_123.npy
# segmentation_label_124.npy
# segmentation_label_125.npy
# segmentation_label_126.npy
# segmentation_label_127.npy

# %%
len(seg_label_filenames)
# Out:
# 128

# %% [markdown]
# ## visualize merlin_output_tif

# %%
import tifffile
ims = tifffile.imread(r'Z:\MERFISH_analysis\20230513-wtBrain_MO4\FiducialCorrelationWarp\images\aligned_fiducial_images30.tif')
