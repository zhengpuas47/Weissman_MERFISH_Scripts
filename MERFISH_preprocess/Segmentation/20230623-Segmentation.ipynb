# %%
import os,sys, re, time
from importlib import reload
import numpy as np
import pandas as pd

#import torch
print(os.getpid())
sys.path.append(r'/lab/weissman_imaging/puzheng/Softwares')
# Out:
# 78157

# %%
import cv2
from ChromAn.src.file_io.data_organization import search_fovs_in_folders, Color_Usage
from ChromAn.src.segmentation_tools.cells import Align_Segmentation

# %%
import merlin
from merlin.util import watershed
from scipy import ndimage
from skimage import morphology
from skimage import segmentation
from copy import copy

# %%
# Cellpose 
import torch
from cellpose import models

# %% [markdown]
# ## Folders

# %%
# data_folder
data_folder = r'/lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2'
# correction
correction_folder = r'/lab/weissman_imaging/puzheng/Corrections/20210621-STORM6_lumencor_from_60_to_50' ## correction for STORM6

segmentation_save_folder = os.path.join(data_folder, 'Segmentation')
if not os.path.exists(segmentation_save_folder):
    print(segmentation_save_folder)
    os.makedirs(segmentation_save_folder)
watershed_folder = os.path.join(segmentation_save_folder, 'watershed')
if not os.path.exists(watershed_folder):
    print(watershed_folder)
    os.makedirs(watershed_folder)

# %%
# transpose with microscope
microscope_file = r'/lab/weissman_imaging/puzheng/Softwares/Weissman_MERFISH_Scripts/merlin_parameters/microscope/storm6_microscope.json'
microscope_params = Align_Segmentation._read_microscope_json(microscope_file)
microscope_params
# Out:
# {'flip_horizontal': False,
#  'flip_vertical': True,
#  'transpose': True,
#  'microns_per_pixel': 0.108}

# %%
# search folders
folders, fovs = search_fovs_in_folders(data_folder)
# Color usage file marks the organization of imaging files
color_usage_filename = os.path.join(data_folder, 'Analysis', 'color_usage.csv')
color_usage_df = Color_Usage(color_usage_filename)
# Out:
# - searching in folder: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2
# -- 11 folders, 507 fovs detected.
# - load color_usage from file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Analysis/color_usage.csv

# %%
# from color_usage, find dapi / polyt / fiducial
dapi_info = color_usage_df.get_dapi_info()[0]
polyt_info = color_usage_df.get_polyt_info()[0]
fiducial_channel = color_usage_df.get_fiducial_channel(color_usage_df)
print(dapi_info, polyt_info, fiducial_channel)
# Out:
# {'hyb': 'H0M1', 'channel': '405'} {'channel': '647', 'hyb': 'H10M11'} 488

# %% [markdown]
# # Run segmentation

# %%
from ChromAn.src.file_io.dax_process import DaxProcesser
from ChromAn.src.visual_tools.interactive import imshow_mark_3d

# %%
for _fov_id, _fov_name in enumerate(fovs):

    _save_id = _fov_id 
    seg_save_file = os.path.join(segmentation_save_folder, f'segmentation_label_{_save_id}.npy')
    if os.path.exists(seg_save_file):
        print(f"Segmentation label file: {seg_save_file} already exists, skip")
        continue
    
    ref_image_file = os.path.join(data_folder, dapi_info['hyb'], _fov_name)
    polyt_image_file = os.path.join(data_folder, polyt_info['hyb'], _fov_name)
    print(f"reference image: {ref_image_file}")
    print(f"PolyT and DAPI image: {polyt_image_file}")
    # load reference DAPI
    _ref_cls = DaxProcesser(ref_image_file, CorrectionFolder=correction_folder, 
                            FiducialChannel=fiducial_channel, DapiChannel=dapi_info['channel'])
    _ref_cls._load_image(sel_channels=[fiducial_channel,dapi_info['channel']])
    _ref_cls._corr_illumination()
    _ref_im = _ref_cls.im_488
    
    # load polyT and DAPI
    _cls = DaxProcesser(polyt_image_file, CorrectionFolder=correction_folder, 
                        FiducialChannel=fiducial_channel)
    _cls._load_image(sel_channels=[polyt_info['channel'],fiducial_channel])
    _cls._corr_illumination()
    _cls._calculate_drift(_ref_im)
    _cls._corr_warpping_drift_chromatic(correction_channels=[polyt_info['channel']], corr_chromatic=False) # removed 405 to increase efficiency
    # extract images
    _dapi_im = copy(getattr(_ref_cls, f"im_{dapi_info['channel']}"))
    _polyt_im = copy(getattr(_cls, f"im_{polyt_info['channel']}"))
    # Run segmentation if target file not exist:
    if os.path.isfile(seg_save_file):
        print(f"- directly load seg from: {seg_save_file}")
        corr_labels3d = np.load(seg_save_file)
    else:
        print(f"- apply microscope corrections")
        dapi_im = Align_Segmentation._correct_image3D_by_microscope_param(_dapi_im, microscope_params)
        polyt_im = Align_Segmentation._correct_image3D_by_microscope_param(_polyt_im, microscope_params)

        # Create cellpose model
        print(f"- run Cellpose segmentation", end=' ')
        _cellpose_start = time.time()
        seg_model = models.CellposeModel(gpu=True, model_type='tissuenet', device=torch.device('cuda:0'))
        # Run cellpose prediction
        labels3d, _, _ = seg_model.eval(np.stack([polyt_im, dapi_im], axis=3), 
                                        batch_size=60, #anisotropy=250/108,
                                        anisotropy=1000/108,
                                        cellprob_threshold=0, 
                                        channels=[1,2], 
                                        diameter=60, 
                                        min_size=2000,
                                        do_3D=True,
                                        )
        print(f"in {time.time()-_cellpose_start:.3f}s.")

        # convert to corrected labels
        corr_labels3d = labels3d.copy() # no modification is required for this one.

        # save this segmentation mask
        print(f"- save to file: {seg_save_file}")
        np.save(seg_save_file.split('.npy')[0], corr_labels3d, )
        
    #break
# Out:
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_0.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_1.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_2.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_3.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_4.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_5.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_6.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_7.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_8.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_9.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_10.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_11.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_12.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_13.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_14.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_15.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_16.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_17.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_18.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_19.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_20.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_21.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_22.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_23.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_24.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_25.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_26.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_27.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_28.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_29.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_30.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_31.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_32.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_33.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_34.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_35.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_36.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_37.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_38.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_39.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_40.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_41.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_42.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_43.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_44.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_45.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_46.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_47.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_48.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_49.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_50.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_51.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_52.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_53.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_54.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_55.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_56.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_57.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_58.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_59.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_60.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_61.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_62.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_63.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_64.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_65.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_66.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_67.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_68.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_69.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_70.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_71.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_72.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_73.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_74.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_75.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_76.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_77.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_78.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_79.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_80.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_81.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_82.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_83.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_84.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_85.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_86.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_87.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_88.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_89.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_90.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_91.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_92.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_93.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_94.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_95.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_96.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_97.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_98.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_99.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_100.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_101.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_102.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_103.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_104.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_105.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_106.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_107.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_108.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_109.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_110.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_111.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_112.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_113.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_114.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_115.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_116.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_117.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_118.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_119.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_120.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_121.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_122.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_123.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_124.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_125.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_126.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_127.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_128.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_129.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_130.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_131.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_132.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_133.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_134.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_135.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_136.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_137.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_138.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_139.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_140.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_141.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_142.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_143.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_144.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_145.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_146.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_147.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_148.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_149.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_150.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_151.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_152.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_153.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_154.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_155.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_156.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_157.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_158.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_159.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_160.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_161.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_162.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_163.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_164.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_165.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_166.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_167.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_168.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_169.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_170.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_171.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_172.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_173.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_174.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_175.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_176.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_177.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_178.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_179.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_180.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_181.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_182.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_183.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_184.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_185.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_186.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_187.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_188.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_189.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_190.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_191.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_192.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_193.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_194.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_195.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_196.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_197.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_198.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_199.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_200.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_201.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_202.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_203.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_204.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_205.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_206.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_207.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_208.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_209.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_210.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_211.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_212.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_213.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_214.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_215.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_216.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_217.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_218.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_219.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_220.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_221.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_222.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_223.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_224.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_225.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_226.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_227.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_228.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_229.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_230.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_231.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_232.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_233.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_234.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_235.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_236.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_237.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_238.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_239.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_240.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_241.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_242.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_243.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_244.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_245.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_246.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_247.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_248.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_249.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_250.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_251.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_252.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_253.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_254.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_255.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_256.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_257.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_258.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_259.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_260.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_261.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_262.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_263.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_264.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_265.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_266.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_267.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_268.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_269.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_270.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_271.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_272.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_273.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_274.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_275.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_276.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_277.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_278.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_279.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_280.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_281.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_282.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_283.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_284.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_285.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_286.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_287.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_288.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_289.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_290.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_291.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_292.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_293.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_294.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_295.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_296.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_297.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_298.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_299.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_300.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_301.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_302.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_303.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_304.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_305.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_306.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_307.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_308.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_309.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_310.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_311.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_312.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_313.npy already exists, skip
# ...
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_403.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_404.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_405.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_406.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_407.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_408.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_409.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_410.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_411.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_412.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_413.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_414.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_415.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_416.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_417.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_418.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_419.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_420.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_421.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_422.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_423.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_424.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_425.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_426.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_427.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_428.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_429.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_430.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_431.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_432.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_433.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_434.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_435.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_436.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_437.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_438.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_439.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_440.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_441.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_442.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_443.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_444.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_445.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_446.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_447.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_448.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_449.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_450.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_451.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_452.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_453.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_454.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_455.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_456.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_457.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_458.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_459.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_460.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_461.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_462.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_463.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_464.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_465.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_466.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_467.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_468.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_469.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_470.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_471.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_472.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_473.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_474.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_475.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_476.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_477.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_478.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_479.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_480.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_481.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_482.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_483.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_484.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_485.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_486.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_487.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_488.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_489.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_490.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_491.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_492.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_493.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_494.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_495.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_496.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_497.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_498.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_499.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_500.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_501.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_502.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_503.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_504.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_505.npy already exists, skip
# Segmentation label file: /lab/weissman_imaging/puzheng/Merfish_seq/20230623-KPtumor_lung_c2/Segmentation/segmentation_label_506.npy already exists, skip

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
# %matplotlib notebook
imshow_mark_3d([polyt_im, dapi_im, corr_labels3d])
# Out:
# <img src="data:image/png;base64,..." width="399.9999913302337">

# %% [markdown]
# # STEP2: Watershed: Optional, potentially make it worse

# %%
watershed_th = 1.6

for _fov_id, _fov_name in enumerate(fovs):
    

    _save_id = _fov_id 
    
    seg_save_file = os.path.join(segmentation_save_folder, f'segmentation_label_{_save_id}.npy')
    watershed_save_file = os.path.join(watershed_folder, f'segmentation_label_{_save_id}.npy')
    if os.path.exists(watershed_save_file):
        print(f"{watershed_save_file} already exists, skip")
        continue
    # Load segmentation
    if os.path.isfile(seg_save_file):
        print(f"- directly load seg from: {seg_save_file}")
        corr_labels3d = np.load(seg_save_file)
    else:
        print(f"- seg file: {seg_save_file} has not been generated yet, skip. ")
        continue
        
    ref_image_file = os.path.join(data_folder, dapi_info['hyb'], _fov_name)
    polyt_image_file = os.path.join(data_folder, polyt_info['hyb'], _fov_name)
    print(f"reference image: {ref_image_file}")
    print(f"PolyT and DAPI image: {polyt_image_file}")
    # load reference DAPI
    _ref_cls = DaxProcesser(ref_image_file, CorrectionFolder=correction_folder, 
                            FiducialChannel=fiducial_channel, DapiChannel=dapi_info['channel'])
    _ref_cls._load_image(sel_channels=[fiducial_channel,dapi_info['channel']])
    _ref_cls._corr_illumination()
    _ref_im = _ref_cls.im_488
    
    # load polyT and DAPI
    _cls = DaxProcesser(polyt_image_file, CorrectionFolder=correction_folder, 
                        FiducialChannel=fiducial_channel)
    _cls._load_image(sel_channels=[polyt_info['channel'],fiducial_channel])
    _cls._corr_illumination()
    _cls._calculate_drift(_ref_im)
    _cls._corr_warpping_drift_chromatic(correction_channels=[polyt_info['channel']], corr_chromatic=False) # removed 405 to increase efficiency
    # extract images
    _dapi_im = copy(getattr(_ref_cls, f"im_{dapi_info['channel']}"))
    _polyt_im = copy(getattr(_cls, f"im_{polyt_info['channel']}"))
    
    
    _save_id = _fov_id 

    dapi_im = Align_Segmentation._correct_image3D_by_microscope_param(_dapi_im, microscope_params)
    polyt_im = Align_Segmentation._correct_image3D_by_microscope_param(_polyt_im, microscope_params)

    # Prepare watershed
    print(f"- run watershed", end=' ')
    _watershed_start = time.time()
    water_input_im = polyt_im
    waterIm, waterMask = watershed.prepare_watershed_images(water_input_im, watershed_th)
    waterMask[corr_labels3d > 0] = True
    waterMask = ndimage.binary_dilation(waterMask, structure=morphology.ball(1))
    # watershed
    new_labels = segmentation.watershed(
                    waterIm, corr_labels3d, mask=waterMask,
                    connectivity=np.ones((3, 3, 3)), watershed_line=True)
    print(f"in {time.time()-_watershed_start:.3f}s.")

    # save
    # save this segmentation mask
    print(f"- save to file: {watershed_save_file}")
    #np.save(watershed_save_file.split('.npy')[0], new_labels, )
    
    break
# Out:
# - directly load seg from: \\wi-bigdata.wi.mit.edu\weissman_imaging\puzheng\msBrain\20230513-wtBrain_MO4_MERFISH_s\Segmentation\segmentation_label_0.npy
# reference image: \\wi-bigdata.wi.mit.edu\weissman_imaging\puzheng\msBrain\20230513-wtBrain_MO4_MERFISH_s\H0M1\Conv_zscan_000.dax
# PolyT and DAPI image: \\wi-bigdata.wi.mit.edu\weissman_imaging\puzheng\msBrain\20230513-wtBrain_MO4_MERFISH_s\H19R1\Conv_zscan_000.dax
# Initialize DaxProcesser for file:\\wi-bigdata.wi.mit.edu\weissman_imaging\puzheng\msBrain\20230513-wtBrain_MO4_MERFISH_s\H0M1\Conv_zscan_000.dax
# - New save file: \\wi-bigdata.wi.mit.edu\weissman_imaging\puzheng\msBrain\20230513-wtBrain_MO4_MERFISH_s\H0M1\Conv_zscan_000_processed.hdf5
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['488', '405'] in 1.732s.
# - Correct illumination for channels: ['488', '405']
# -- Keep channels: ['488', '405'] for corr_illumination.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 1.120s.
# -- corrected illumination for channel 405 in 1.183s.
# - Finished illumination correction in 2.731s.
# Initialize DaxProcesser for file:\\wi-bigdata.wi.mit.edu\weissman_imaging\puzheng\msBrain\20230513-wtBrain_MO4_MERFISH_s\H19R1\Conv_zscan_000.dax
# - New save file: \\wi-bigdata.wi.mit.edu\weissman_imaging\puzheng\msBrain\20230513-wtBrain_MO4_MERFISH_s\H19R1\Conv_zscan_000_processed.hdf5
# -- all used channels: ['647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['647', '488'] in 0.770s.
# - Correct illumination for channels: ['647', '488']
# -- Keep channels: ['647', '488'] for corr_illumination.
# - Start illumination correction for channels:['647', '488'].
# -- loading illumination correction profile from file:
# 	 647 illumination_correction_647_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 647 in 1.208s.
# -- corrected illumination for channel 488 in 1.195s.
# - Finished illumination correction in 2.691s.
# + Calculate drift with fiducial_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [  0.   -31.77 -46.89] in 0.837s.
# -- drift 1: [ 1.000e-02 -3.159e+01 -4.692e+01] in 0.850s.
# -- drift 2: [ 1.000e-02 -3.174e+01 -4.685e+01] in 0.799s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['647'], chromatic:['647']
# - Start 3D warpping for channels:['647'].
# -- loading chromatic correction profile from file:
# 	 647 None
# -- corrected warp for channel 647 in 7.051s.
# - Finished warp correction in 7.051s.
# - run watershed in 100.432s.
# - save to file: \\wi-bigdata.wi.mit.edu\weissman_imaging\puzheng\msBrain\20230513-wtBrain_MO4_MERFISH_s\Segmentation\watershed\segmentation_label_0.npy

# %%
imshow_mark_3d([new_labels, corr_labels3d])
# Out:
# <img src="data:image/png;base64,..." width="399.999976880624">

# %% [markdown]
# ## visualize merlin_output_tif

# %%
import tifffile
ims = tifffile.imread(r'Z:\MERFISH_analysis\20230513-wtBrain_MO4\FiducialCorrelationWarp\images\aligned_fiducial_images30.tif')
