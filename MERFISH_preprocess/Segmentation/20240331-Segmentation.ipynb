# %%
#import torch
import os, sys, re, time
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
#import torch
print(os.getpid())
sys.path.append(r"/lab/weissman_imaging/puzheng/Softwares")
# Out:
# 82409

# %%
import cv2
from ChromAn.src.file_io.data_organization import search_fovs_in_folders, Color_Usage
from ChromAn.src.segmentation_tools.cells import Align_Segmentation

# %%
import merlin
from merlin.util import watershed
from scipy import ndimage
from skimage import morphology
from skimage import segmentation
from copy import copy

# %%
# Cellpose 
from cellpose import models

# %% [markdown]
# ## Folders

# %%
# data_folder
data_folder = r'/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna'
# correction
correction_folder = r'/lab/weissman_imaging/puzheng/Corrections/20230824-Merscope01'

segmentation_save_folder = os.path.join(data_folder, 'Segmentation')
if not os.path.exists(segmentation_save_folder):
    print(segmentation_save_folder)
    os.makedirs(segmentation_save_folder)
watershed_folder = os.path.join(segmentation_save_folder, 'watershed')
if not os.path.exists(watershed_folder):
    print(watershed_folder)
    os.makedirs(watershed_folder)
# Out:
# /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation
# /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/watershed

# %%
# transpose with microscope
parameter_folder = r'/lab/weissman_imaging/puzheng/Softwares/Weissman_MERFISH_Scripts/merlin_parameters'
microscope_file = os.path.join(parameter_folder, 'microscope', 'merscope01_microscope.json')
microscope_params = Align_Segmentation._read_microscope_json(microscope_file)
microscope_params
# Out:
# {'flip_horizontal': False,
#  'flip_vertical': True,
#  'transpose': True,
#  'microns_per_pixel': 0.107,
#  'image_dimensions': [2304, 2304]}

# %%
# search folders
folders, fovs = search_fovs_in_folders(data_folder)
# Color usage file marks the organization of imaging files
color_usage_filename = os.path.join(data_folder, 'Analysis', 'color_usage.csv')
color_usage_df = Color_Usage(color_usage_filename)
# Out:
# - searching in folder: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna
# -- 9 folders, 58 fovs detected.
# - load color_usage from file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Analysis/color_usage.csv

# %%
# from color_usage, find dapi / polyt / fiducial
dapi_info = color_usage_df.get_dapi_info()[0]
polyt_info = color_usage_df.get_polyt_info()[0]
fiducial_channel = color_usage_df.get_fiducial_channel(color_usage_df)
print(dapi_info, polyt_info, fiducial_channel)
# Out:
# {'hyb': 'H0M1', 'channel': '405'} {'channel': '637', 'hyb': 'H8M9'} 477

# %% [markdown]
# # Run segmentation

# %%
from ChromAn.src.file_io.dax_process import DaxProcesser
from ChromAn.src.visual_tools.interactive import imshow_mark_3d
from merlin.analysis.segment import CellPoseSegment

# %%
from importlib import reload

# %%
import ChromAn
reload(ChromAn.src.file_io.dax_process)
# Out:
# <module 'ChromAn.src.file_io.dax_process' from '/lab/weissman_imaging/puzheng/Softwares/ChromAn/src/file_io/dax_process.py'>

# %%
for _fov_id, _fov_name in enumerate(fovs):

    _save_id = _fov_id 
    seg_save_file = os.path.join(segmentation_save_folder, f'segmentation_label_{_save_id}.npy')
    if os.path.exists(seg_save_file):
        print(f"Segmentation label file: {seg_save_file} already exists, skip")
        continue
    
    ref_image_file = os.path.join(data_folder, dapi_info['hyb'], _fov_name)
    polyt_image_file = os.path.join(data_folder, polyt_info['hyb'], _fov_name)
    print(f"reference image: {ref_image_file}")
    print(f"PolyT and DAPI image: {polyt_image_file}")
    # load reference DAPI
    _ref_cls = DaxProcesser(ref_image_file, CorrectionFolder=correction_folder, 
                            FiducialChannel=fiducial_channel, DapiChannel=dapi_info['channel'])
    _ref_cls._load_image(sel_channels=[fiducial_channel,dapi_info['channel']])
    #_ref_cls._corr_illumination()
    _ref_im = getattr(_ref_cls, f'im_{fiducial_channel}')
    
    # load polyT and DAPI
    _cls = DaxProcesser(polyt_image_file, CorrectionFolder=correction_folder, 
                        FiducialChannel=fiducial_channel)
    _cls._load_image(sel_channels=[polyt_info['channel'],fiducial_channel])
    _cls.ref_correction_channel = '637'
    #_cls._corr_illumination()
    _cls._calculate_drift(_ref_im, )
    _cls._corr_warpping_drift_chromatic(correction_channels=[polyt_info['channel']], corr_chromatic=False) # removed 405 to increase efficiency
    
    _dapi_im = getattr(_ref_cls, f"im_{dapi_info['channel']}")
    _polyt_im = getattr(_cls, f"im_{polyt_info['channel']}")
    # Run segmentation if target file not exist:
    if os.path.isfile(seg_save_file):
        print(f"- directly load seg from: {seg_save_file}")
        corr_labels3d = np.load(seg_save_file)
    else:
        print(f"- apply microscope corrections")
        dapi_im = Align_Segmentation._correct_image3D_by_microscope_param(_dapi_im, microscope_params)
        polyt_im = Align_Segmentation._correct_image3D_by_microscope_param(_polyt_im, microscope_params)

        # Create cellpose model
        print(f"- run Cellpose segmentation", end=' ')
        _cellpose_start = time.time()
        seg_model = models.CellposeModel(gpu=True, model_type='TN2')
        # Run cellpose prediction
        labels3d, _, _ = seg_model.eval(np.stack([polyt_im, dapi_im], axis=3), 
                                        #batch_size=60, #anisotropy=250/108,
                                        anisotropy=1000/108,
                                        cellprob_threshold=0, 
                                        channels=[1,2], 
                                        diameter=100, 
                                        min_size=2000,
                                        do_3D=False,
                                        )
        print(f"in {time.time()-_cellpose_start:.3f}s.")

        # convert to corrected labels
        corr_labels3d = CellPoseSegment.combine_2d_segmentation_masks_into_3d(labels3d)

        # save this segmentation mask
        print(f"- save to file: {seg_save_file}")
        np.save(seg_save_file.split('.npy')[0], corr_labels3d, )
    
    #break
# Out:
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_00.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_00.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_00.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_00_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 1.895s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_00.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_00_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.181s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.   5.66 4.07] in 0.668s.
# -- drift 1: [0.   5.51 4.27] in 0.461s.
# -- drift 2: [0.   5.49 4.24] in 0.464s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.613s.
# - Finished warp correction in 8.613s.
# - apply microscope corrections
# - run Cellpose segmentation in 52.204s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_0.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_01.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_01.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_01.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_01_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 1.813s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_01.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_01_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.050s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.01  7.65  2.97] in 0.637s.
# -- drift 1: [0.   7.94 3.13] in 0.451s.
# -- drift 2: [-0.02  7.42  3.04] in 0.468s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.623s.
# - Finished warp correction in 8.623s.
# - apply microscope corrections
# - run Cellpose segmentation in 41.388s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_1.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_02.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_02.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_02.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_02_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 1.994s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_02.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_02_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.029s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.01  5.27  1.72] in 0.612s.
# -- drift 1: [0.   5.22 1.7 ] in 0.449s.
# -- drift 2: [0.   5.23 1.67] in 0.461s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.615s.
# - Finished warp correction in 8.615s.
# - apply microscope corrections
# - run Cellpose segmentation in 51.088s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_2.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_03.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_03.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_03.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_03_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 1.900s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_03.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_03_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.081s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [ 0.    6.87 -0.19] in 0.616s.
# -- drift 1: [ 0.    6.81 -0.04] in 0.458s.
# -- drift 2: [ 0.   6.9 -0.2] in 0.465s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.675s.
# - Finished warp correction in 8.675s.
# - apply microscope corrections
# - run Cellpose segmentation in 45.002s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_3.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_04.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_04.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_04.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_04_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 1.898s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_04.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_04_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.145s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.   2.93 2.07] in 0.615s.
# -- drift 1: [0.   2.94 3.  ] in 0.456s.
# -- drift 2: [0.   2.87 2.2 ] in 0.462s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.665s.
# - Finished warp correction in 8.665s.
# - apply microscope corrections
# - run Cellpose segmentation in 41.186s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_4.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_05.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_05.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_05.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_05_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 1.877s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_05.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_05_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.101s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.   5.92 1.51] in 0.543s.
# -- drift 1: [0.   5.84 1.57] in 0.445s.
# -- drift 2: [0.   5.95 1.38] in 0.443s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.637s.
# - Finished warp correction in 8.637s.
# - apply microscope corrections
# - run Cellpose segmentation in 44.236s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_5.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_06.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_06.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_06.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_06_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 2.001s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_06.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_06_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.081s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.01  5.59  1.11] in 0.597s.
# -- drift 1: [0.   5.36 1.09] in 0.443s.
# -- drift 2: [0.   5.54 1.05] in 0.450s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.622s.
# - Finished warp correction in 8.622s.
# - apply microscope corrections
# - run Cellpose segmentation in 65.484s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_6.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_07.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_07.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_07.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_07_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 1.807s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_07.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_07_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.084s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.   4.72 1.47] in 0.598s.
# -- drift 1: [0.   4.69 1.51] in 0.449s.
# -- drift 2: [0.   4.68 1.51] in 0.459s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.650s.
# - Finished warp correction in 8.650s.
# - apply microscope corrections
# - run Cellpose segmentation in 48.401s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_7.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_08.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_08.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_08.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_08_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 1.831s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_08.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_08_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.172s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.02  6.23  1.95] in 0.601s.
# -- drift 1: [-0.01  6.04  1.91] in 0.446s.
# -- drift 2: [-0.01  6.11  1.9 ] in 0.447s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.600s.
# - Finished warp correction in 8.601s.
# - apply microscope corrections
# - run Cellpose segmentation in 55.618s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_8.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_09.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_09.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_09.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_09_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 1.987s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_09.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_09_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.136s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.   3.08 2.09] in 0.601s.
# -- drift 1: [0.   3.15 2.18] in 0.447s.
# -- drift 2: [0.   3.09 2.25] in 0.448s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.603s.
# - Finished warp correction in 8.603s.
# - apply microscope corrections
# - run Cellpose segmentation in 47.457s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_9.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_10.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_10.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_10.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_10_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 1.848s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_10.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_10_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.059s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.   5.7  3.36] in 0.608s.
# -- drift 1: [0.   5.65 3.37] in 0.451s.
# -- drift 2: [0.   5.63 3.36] in 0.462s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.835s.
# - Finished warp correction in 8.836s.
# - apply microscope corrections
# - run Cellpose segmentation in 43.994s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_10.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_11.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_11.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_11.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_11_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 2.122s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_11.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_11_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.037s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.01  5.29  3.66] in 0.602s.
# -- drift 1: [0.   5.13 3.61] in 0.445s.
# -- drift 2: [0.   5.14 3.65] in 0.453s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.616s.
# - Finished warp correction in 8.617s.
# - apply microscope corrections
# - run Cellpose segmentation in 53.406s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_11.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_12.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_12.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_12.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_12_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 2.038s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_12.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_12_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.269s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.   4.   3.75] in 0.606s.
# -- drift 1: [0.   3.98 3.66] in 0.457s.
# -- drift 2: [0.   4.03 3.71] in 0.458s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.618s.
# - Finished warp correction in 8.618s.
# - apply microscope corrections
# - run Cellpose segmentation in 52.474s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_12.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_13.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_13.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_13.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_13_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 2.218s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_13.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_13_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.169s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.   5.66 2.16] in 0.604s.
# -- drift 1: [0.   5.63 2.24] in 0.457s.
# -- drift 2: [0.   5.6  2.31] in 0.463s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.637s.
# - Finished warp correction in 8.637s.
# - apply microscope corrections
# - run Cellpose segmentation in 53.158s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_13.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_14.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_14.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_14.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_14_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 1.888s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_14.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_14_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.049s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.   7.07 2.54] in 0.600s.
# -- drift 1: [0.   6.94 2.63] in 0.442s.
# -- drift 2: [0.   7.01 2.56] in 0.453s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.609s.
# - Finished warp correction in 8.610s.
# - apply microscope corrections
# - run Cellpose segmentation in 47.305s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_14.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_15.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_15.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_15.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_15_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 2.221s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_15.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_15_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.137s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.   4.95 3.06] in 0.593s.
# -- drift 1: [0.   4.96 3.05] in 0.433s.
# -- drift 2: [0.   4.99 3.03] in 0.448s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.613s.
# - Finished warp correction in 8.613s.
# - apply microscope corrections
# - run Cellpose segmentation in 48.255s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_15.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_16.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_16.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_16.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_16_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 2.033s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_16.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_16_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.099s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.   3.55 2.2 ] in 0.587s.
# -- drift 1: [0.   3.52 2.17] in 0.440s.
# -- drift 2: [0.   3.45 2.13] in 0.446s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.641s.
# - Finished warp correction in 8.641s.
# - apply microscope corrections
# - run Cellpose segmentation in 52.683s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_16.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_17.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_17.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_17.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_17_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 1.826s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_17.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_17_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.261s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.   5.68 2.03] in 0.581s.
# -- drift 1: [0.   5.5  2.13] in 0.439s.
# -- drift 2: [0.   5.54 2.11] in 0.445s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.617s.
# - Finished warp correction in 8.617s.
# - apply microscope corrections
# - run Cellpose segmentation in 51.188s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_17.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_18.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_18.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_18.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_18_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 1.804s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_18.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_18_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.081s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.   6.6  2.11] in 0.589s.
# -- drift 1: [-0.01  6.5   2.14] in 0.440s.
# -- drift 2: [-0.01  6.65  2.16] in 0.443s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.654s.
# - Finished warp correction in 8.655s.
# - apply microscope corrections
# - run Cellpose segmentation in 52.916s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_18.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_19.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_19.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_19.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_19_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 1.940s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_19.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_19_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.176s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.   4.66 1.74] in 0.530s.
# -- drift 1: [-0.01  4.56  1.75] in 0.441s.
# -- drift 2: [0.   4.57 1.8 ] in 0.444s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.649s.
# - Finished warp correction in 8.649s.
# - apply microscope corrections
# - run Cellpose segmentation in 45.681s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_19.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_20.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_20.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_20.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_20_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 2.099s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_20.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_20_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.166s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.   5.44 0.71] in 0.593s.
# -- drift 1: [0.   5.39 0.73] in 0.445s.
# -- drift 2: [0.   5.37 0.79] in 0.445s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.623s.
# - Finished warp correction in 8.623s.
# - apply microscope corrections
# - run Cellpose segmentation in 50.418s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_20.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_21.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_21.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_21.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_21_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 2.006s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_21.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_21_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.009s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.01  5.34  1.99] in 0.607s.
# -- drift 1: [-0.01  5.27  2.05] in 0.444s.
# -- drift 2: [0.   5.3  2.04] in 0.451s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.649s.
# - Finished warp correction in 8.649s.
# - apply microscope corrections
# - run Cellpose segmentation in 54.287s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_21.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_22.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_22.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_22.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_22_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 2.064s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_22.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_22_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.129s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.   5.87 0.89] in 0.536s.
# -- drift 1: [0.   5.77 0.85] in 0.450s.
# -- drift 2: [0.   5.87 0.87] in 0.451s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.631s.
# - Finished warp correction in 8.632s.
# - apply microscope corrections
# - run Cellpose segmentation in 46.555s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_22.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_23.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_23.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_23.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_23_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 2.001s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_23.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_23_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.121s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.01  5.    2.68] in 0.595s.
# -- drift 1: [0.   4.89 2.56] in 0.442s.
# -- drift 2: [0.   4.89 2.61] in 0.449s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.605s.
# - Finished warp correction in 8.605s.
# - apply microscope corrections
# - run Cellpose segmentation in 48.827s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_23.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_24.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_24.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_24.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_24_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 1.941s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_24.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_24_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.050s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.   4.69 2.09] in 0.603s.
# -- drift 1: [0.   4.62 2.25] in 0.442s.
# -- drift 2: [0.   4.61 2.26] in 0.450s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.633s.
# - Finished warp correction in 8.633s.
# - apply microscope corrections
# - run Cellpose segmentation in 53.883s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_24.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_25.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_25.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_25.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_25_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 1.896s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_25.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_25_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.121s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.01  5.93  2.69] in 0.589s.
# -- drift 1: [0.   5.55 2.77] in 0.437s.
# -- drift 2: [-0.01  6.12  2.67] in 0.450s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.624s.
# - Finished warp correction in 8.624s.
# - apply microscope corrections
# - run Cellpose segmentation in 49.208s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_25.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_26.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_26.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_26.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_26_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 2.038s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_26.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_26_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.065s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.01 5.44 1.89] in 0.590s.
# -- drift 1: [0.   5.54 1.94] in 0.435s.
# -- drift 2: [0.   5.44 1.86] in 0.447s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.621s.
# - Finished warp correction in 8.621s.
# - apply microscope corrections
# - run Cellpose segmentation in 51.768s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_26.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_27.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_27.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_27.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_27_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 1.834s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_27.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_27_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.335s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.   7.11 2.39] in 0.568s.
# -- drift 1: [-0.01  7.16  2.38] in 0.452s.
# -- drift 2: [0.   7.02 2.53] in 0.451s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.612s.
# - Finished warp correction in 8.612s.
# - apply microscope corrections
# - run Cellpose segmentation in 45.566s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_27.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_28.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_28.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_28.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_28_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 1.919s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_28.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_28_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.207s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.   4.19 3.3 ] in 0.557s.
# -- drift 1: [0.   4.33 3.34] in 0.455s.
# -- drift 2: [0.   4.26 3.3 ] in 0.452s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.622s.
# - Finished warp correction in 8.622s.
# - apply microscope corrections
# - run Cellpose segmentation in 42.917s.
# ...
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_48.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_48_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.141s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.   4.56 4.06] in 0.614s.
# -- drift 1: [-0.01  4.55  4.06] in 0.451s.
# -- drift 2: [0.   4.49 3.98] in 0.454s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.627s.
# - Finished warp correction in 8.627s.
# - apply microscope corrections
# - run Cellpose segmentation in 52.530s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_48.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_49.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_49.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_49.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_49_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 2.038s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_49.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_49_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.186s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.01  4.81  0.82] in 0.599s.
# -- drift 1: [0.   4.69 0.95] in 0.459s.
# -- drift 2: [0.   4.65 0.97] in 0.460s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.647s.
# - Finished warp correction in 8.647s.
# - apply microscope corrections
# - run Cellpose segmentation in 46.210s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_49.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_50.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_50.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_50.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_50_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 1.826s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_50.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_50_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.224s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.01  5.61  1.9 ] in 0.597s.
# -- drift 1: [-0.01  5.51  1.91] in 0.463s.
# -- drift 2: [-0.01  5.52  1.95] in 0.459s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.617s.
# - Finished warp correction in 8.618s.
# - apply microscope corrections
# - run Cellpose segmentation in 52.495s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_50.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_51.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_51.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_51.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_51_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 1.921s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_51.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_51_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.108s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.   4.31 1.95] in 0.612s.
# -- drift 1: [-0.03  4.35  2.01] in 0.449s.
# -- drift 2: [-0.01  4.36  1.91] in 0.456s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.628s.
# - Finished warp correction in 8.628s.
# - apply microscope corrections
# - run Cellpose segmentation in 40.062s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_51.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_52.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_52.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_52.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_52_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 1.857s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_52.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_52_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.277s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.01  5.42  1.09] in 0.592s.
# -- drift 1: [-0.02  5.26  1.  ] in 0.441s.
# -- drift 2: [0.   5.28 0.92] in 0.448s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.635s.
# - Finished warp correction in 8.635s.
# - apply microscope corrections
# - run Cellpose segmentation in 58.163s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_52.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_53.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_53.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_53.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_53_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 1.915s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_53.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_53_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.686s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.   3.12 4.01] in 0.589s.
# -- drift 1: [0.   3.09 4.09] in 0.447s.
# -- drift 2: [0.   3.04 4.14] in 0.452s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.670s.
# - Finished warp correction in 8.670s.
# - apply microscope corrections
# - run Cellpose segmentation in 46.415s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_53.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_54.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_54.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_54.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_54_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 2.024s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_54.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_54_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.073s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.   5.14 2.23] in 0.599s.
# -- drift 1: [0.   5.09 2.22] in 0.449s.
# -- drift 2: [0.   5.11 2.11] in 0.455s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.630s.
# - Finished warp correction in 8.630s.
# - apply microscope corrections
# - run Cellpose segmentation in 53.565s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_54.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_55.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_55.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_55.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_55_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 1.891s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_55.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_55_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.144s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.01  5.14  1.95] in 0.607s.
# -- drift 1: [-0.01  4.98  1.88] in 0.448s.
# -- drift 2: [-0.02  5.09  1.96] in 0.451s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.633s.
# - Finished warp correction in 8.633s.
# - apply microscope corrections
# - run Cellpose segmentation in 38.202s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_55.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_56.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_56.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_56.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_56_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 1.652s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_56.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_56_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.012s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [-0.03  4.89  0.86] in 0.525s.
# -- drift 1: [-0.02  4.88  0.81] in 0.465s.
# -- drift 2: [-0.05  4.78  0.53] in 0.458s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.642s.
# - Finished warp correction in 8.642s.
# - apply microscope corrections
# - run Cellpose segmentation in 49.103s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_56.npy
# reference image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_57.dax
# PolyT and DAPI image: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_57.dax
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_57.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H0M1/Conv_zscan_57_processed.hdf5
# -- all used channels: ['748', '637', '477', '405']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['477', '405'] in 1.963s.
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_57.dax
# - New save file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/H8M9/Conv_zscan_57_processed.hdf5
# -- all used channels: ['637', '477']
# -- single image size: [  11 2304 2304]
# - Loaded images for channels:['637', '477'] in 1.060s.
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0.   4.95 2.12] in 0.596s.
# -- drift 1: [0.   4.95 2.16] in 0.459s.
# -- drift 2: [0.   4.97 2.07] in 0.456s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['637'], chromatic:[]
# - Start 3D warpping for channels:['637'].
# -- corrected warp for channel 637 in 8.611s.
# - Finished warp correction in 8.611s.
# - apply microscope corrections
# - run Cellpose segmentation in 38.781s.
# - save to file: /lab/weissman_imaging/puzheng/4T1Tumor/20240331-4T1fullyEdited_MF4dna/Segmentation/segmentation_label_57.npy

# %%
# %matplotlib notebook
imshow_mark_3d([_dapi_im, _polyt_im, corr_labels3d])
# Out:
# <img src="data:image/png;base64,..." width="399.9999913302337">

# %% [markdown]
# # STEP2: Watershed: Optional, potentially make it worse

# %%
watershed_th = 1.6

for _fov_id, _fov_name in enumerate(fovs):
    

    _save_id = _fov_id 
    
    seg_save_file = os.path.join(segmentation_save_folder, f'segmentation_label_{_save_id}.npy')
    watershed_save_file = os.path.join(watershed_folder, f'segmentation_label_{_save_id}.npy')
    if os.path.exists(watershed_save_file):
        print(f"{watershed_save_file} already exists, skip")
        continue
    # Load segmentation
    if os.path.isfile(seg_save_file):
        print(f"- directly load seg from: {seg_save_file}")
        corr_labels3d = np.load(seg_save_file)
    else:
        print(f"- seg file: {seg_save_file} has not been generated yet, skip. ")
        continue
        
    ref_image_file = os.path.join(data_folder, dapi_info['hyb'], _fov_name)
    polyt_image_file = os.path.join(data_folder, polyt_info['hyb'], _fov_name)
    print(f"reference image: {ref_image_file}")
    print(f"PolyT and DAPI image: {polyt_image_file}")
    # load reference DAPI
    _ref_cls = DaxProcesser(ref_image_file, CorrectionFolder=correction_folder, 
                            FiducialChannel=fiducial_channel, DapiChannel=dapi_info['channel'])
    _ref_cls._load_image(sel_channels=[fiducial_channel,dapi_info['channel']])
    _ref_cls._corr_illumination()
    _ref_im = _ref_cls.im_488
    
    # load polyT and DAPI
    _cls = DaxProcesser(polyt_image_file, CorrectionFolder=correction_folder, 
                        FiducialChannel=fiducial_channel)
    _cls._load_image(sel_channels=[polyt_info['channel'],fiducial_channel])
    _cls._corr_illumination()
    _cls._calculate_drift(_ref_im)
    _cls._corr_warpping_drift_chromatic(correction_channels=[polyt_info['channel']], corr_chromatic=False) # removed 405 to increase efficiency
    # extract images
    _dapi_im = copy(getattr(_ref_cls, f"im_{dapi_info['channel']}"))
    _polyt_im = copy(getattr(_cls, f"im_{polyt_info['channel']}"))
    
    
    _save_id = _fov_id 

    dapi_im = Align_Segmentation._correct_image3D_by_microscope_param(_dapi_im, microscope_params)
    polyt_im = Align_Segmentation._correct_image3D_by_microscope_param(_polyt_im, microscope_params)

    # Prepare watershed
    print(f"- run watershed", end=' ')
    _watershed_start = time.time()
    water_input_im = polyt_im
    waterIm, waterMask = watershed.prepare_watershed_images(water_input_im, watershed_th)
    waterMask[corr_labels3d > 0] = True
    waterMask = ndimage.binary_dilation(waterMask, structure=morphology.ball(1))
    # watershed
    new_labels = segmentation.watershed(
                    waterIm, corr_labels3d, mask=waterMask,
                    connectivity=np.ones((3, 3, 3)), watershed_line=True)
    print(f"in {time.time()-_watershed_start:.3f}s.")

    # save
    # save this segmentation mask
    print(f"- save to file: {watershed_save_file}")
    #np.save(watershed_save_file.split('.npy')[0], new_labels, )
    
    break
# Out:
# - directly load seg from: \\wi-bigdata.wi.mit.edu\weissman_imaging\puzheng\msBrain\20230513-wtBrain_MO4_MERFISH_s\Segmentation\segmentation_label_0.npy
# reference image: \\wi-bigdata.wi.mit.edu\weissman_imaging\puzheng\msBrain\20230513-wtBrain_MO4_MERFISH_s\H0M1\Conv_zscan_000.dax
# PolyT and DAPI image: \\wi-bigdata.wi.mit.edu\weissman_imaging\puzheng\msBrain\20230513-wtBrain_MO4_MERFISH_s\H19R1\Conv_zscan_000.dax
# Initialize DaxProcesser for file:\\wi-bigdata.wi.mit.edu\weissman_imaging\puzheng\msBrain\20230513-wtBrain_MO4_MERFISH_s\H0M1\Conv_zscan_000.dax
# - New save file: \\wi-bigdata.wi.mit.edu\weissman_imaging\puzheng\msBrain\20230513-wtBrain_MO4_MERFISH_s\H0M1\Conv_zscan_000_processed.hdf5
# -- all used channels: ['750', '647', '488', '405']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['488', '405'] in 1.732s.
# - Correct illumination for channels: ['488', '405']
# -- Keep channels: ['488', '405'] for corr_illumination.
# - Start illumination correction for channels:['488', '405'].
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# -- corrected illumination for channel 488 in 1.120s.
# -- corrected illumination for channel 405 in 1.183s.
# - Finished illumination correction in 2.731s.
# Initialize DaxProcesser for file:\\wi-bigdata.wi.mit.edu\weissman_imaging\puzheng\msBrain\20230513-wtBrain_MO4_MERFISH_s\H19R1\Conv_zscan_000.dax
# - New save file: \\wi-bigdata.wi.mit.edu\weissman_imaging\puzheng\msBrain\20230513-wtBrain_MO4_MERFISH_s\H19R1\Conv_zscan_000_processed.hdf5
# -- all used channels: ['647', '488']
# -- single image size: [  13 2048 2048]
# - Loaded images for channels:['647', '488'] in 0.770s.
# - Correct illumination for channels: ['647', '488']
# -- Keep channels: ['647', '488'] for corr_illumination.
# - Start illumination correction for channels:['647', '488'].
# -- loading illumination correction profile from file:
# 	 647 illumination_correction_647_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- corrected illumination for channel 647 in 1.208s.
# -- corrected illumination for channel 488 in 1.195s.
# - Finished illumination correction in 2.691s.
# + Calculate drift with fiducial_channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [  0.   -31.77 -46.89] in 0.837s.
# -- drift 1: [ 1.000e-02 -3.159e+01 -4.692e+01] in 0.850s.
# -- drift 2: [ 1.000e-02 -3.174e+01 -4.685e+01] in 0.799s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - Start warpping images drift:['647'], chromatic:['647']
# - Start 3D warpping for channels:['647'].
# -- loading chromatic correction profile from file:
# 	 647 None
# -- corrected warp for channel 647 in 7.051s.
# - Finished warp correction in 7.051s.
# - run watershed in 100.432s.
# - save to file: \\wi-bigdata.wi.mit.edu\weissman_imaging\puzheng\msBrain\20230513-wtBrain_MO4_MERFISH_s\Segmentation\watershed\segmentation_label_0.npy

# %%
imshow_mark_3d([new_labels, corr_labels3d])
# Out:
# <img src="data:image/png;base64,..." width="399.999976880624">

# %%
# Copy segmentation labels
data_master_folder = r'/lab/weissman_imaging/puzheng/MERFISH_data'
analysis_master_folder = r'/lab/weissman_imaging/puzheng/MERFISH_analysis'
print(os.listdir(data_master_folder))
# Out:
# ['20240331-4T1fullyEdited_MF4dna', '.DS_Store']

# %%
experiment_date = os.path.basename(data_folder).split('-')[0]
print(experiment_date)
for _fd in os.listdir(data_master_folder):
    if experiment_date in _fd:
        break
analysis_folder = os.path.join(analysis_master_folder, _fd)
print(analysis_folder)
# Out:
# 20240331
# /lab/weissman_imaging/puzheng/MERFISH_analysis/20240331-4T1fullyEdited_MF4dna

# %%
from shutil import copyfile

# %%
# manually select data to be transferred:
segmentation_target_folder = os.path.join(analysis_folder, 'CellPoseSegment', 'segmentation_label')
print(segmentation_target_folder)
if not os.path.exists(segmentation_target_folder):
    os.makedirs(segmentation_target_folder)
# copy
seg_label_filenames = [os.path.join(segmentation_save_folder, _f) 
                       for _f in os.listdir(segmentation_save_folder) 
                       if 'segmentation_label' in _f and '.npy' in _f]

for _f in seg_label_filenames:
    print(os.path.basename(_f))
    copyfile(_f, os.path.join(segmentation_target_folder, os.path.basename(_f)))
# Out:
# /lab/weissman_imaging/puzheng/MERFISH_analysis/20240331-4T1fullyEdited_MF4dna/CellPoseSegment/segmentation_label
# segmentation_label_0.npy
# segmentation_label_1.npy
# segmentation_label_2.npy
# segmentation_label_3.npy
# segmentation_label_4.npy
# segmentation_label_5.npy
# segmentation_label_6.npy
# segmentation_label_7.npy
# segmentation_label_8.npy
# segmentation_label_9.npy
# segmentation_label_10.npy
# segmentation_label_11.npy
# segmentation_label_12.npy
# segmentation_label_13.npy
# segmentation_label_14.npy
# segmentation_label_15.npy
# segmentation_label_16.npy
# segmentation_label_17.npy
# segmentation_label_18.npy
# segmentation_label_19.npy
# segmentation_label_20.npy
# segmentation_label_21.npy
# segmentation_label_22.npy
# segmentation_label_23.npy
# segmentation_label_24.npy
# segmentation_label_25.npy
# segmentation_label_26.npy
# segmentation_label_27.npy
# segmentation_label_28.npy
# segmentation_label_29.npy
# segmentation_label_30.npy
# segmentation_label_31.npy
# segmentation_label_32.npy
# segmentation_label_33.npy
# segmentation_label_34.npy
# segmentation_label_35.npy
# segmentation_label_36.npy
# segmentation_label_37.npy
# segmentation_label_38.npy
# segmentation_label_39.npy
# segmentation_label_40.npy
# segmentation_label_41.npy
# segmentation_label_42.npy
# segmentation_label_43.npy
# segmentation_label_44.npy
# segmentation_label_45.npy
# segmentation_label_46.npy
# segmentation_label_47.npy
# segmentation_label_48.npy
# segmentation_label_49.npy
# segmentation_label_50.npy
# segmentation_label_51.npy
# segmentation_label_52.npy
# segmentation_label_53.npy
# segmentation_label_54.npy
# segmentation_label_55.npy
# segmentation_label_56.npy
# segmentation_label_57.npy

# %% [markdown]
# ## visualize merlin_output_tif

# %%
import tifffile
ims = tifffile.imread(r'Z:\MERFISH_analysis\20230513-wtBrain_MO4\FiducialCorrelationWarp\images\aligned_fiducial_images30.tif')
