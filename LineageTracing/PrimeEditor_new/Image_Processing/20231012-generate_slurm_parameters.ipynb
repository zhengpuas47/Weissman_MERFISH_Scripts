# %%
# Basic imports
import os,sys,re
from importlib import reload
import numpy as np
import pandas as pd
#import torch
print(os.getpid())
# Out:
# 2030168

# %%
# ChromAn related imports
sys.path.append(r'/lab/weissman_imaging/puzheng/Softwares/') # parent folder of ChromAn

from ChromAn.src import file_io

from ChromAn.src.file_io import dax_process
from ChromAn.src.file_io import data_organization
from ChromAn.src.visual_tools import interactive

# %% [markdown]
# # Folders

# %%
# data folder
data_folder = r'/lab/weissman_imaging/puzheng/PE_LT/20231012-4T1v21x_50k0927_digestion_test/37c_2day'
# scan subfolders
folders, fovs = data_organization.search_fovs_in_folders(data_folder)
# analysis folder
analysis_folder = os.path.join(data_folder, 'Analysis')
if not os.path.exists(analysis_folder):
    os.makedirs(analysis_folder)
# Out:
# - searching in folder: /lab/weissman_imaging/puzheng/PE_LT/20231012-4T1v21x_50k0927_digestion_test/37c_1day
# -- 1 folders, 326 fovs detected.

# %%
# color usage
color_usage_filename = os.path.join(data_folder, 'Analysis', 'color_usage_clearing.csv')
color_usage_df = data_organization.Color_Usage(color_usage_filename)
# Out:
# - load color_usage from file: /lab/weissman_imaging/puzheng/PE_LT/20231012-4T1v21x_50k0927_digestion_test/37c_1day/Analysis/color_usage_clearing.csv

# %%
image_infos = color_usage_df.iloc[color_usage_df.get_hyb_id('H0M1')]
print(image_infosfos)
# Out:
# 748      m52
# 637      m53
# 545    empty
# 477    beads
# 405     DAPI
# Name: H0M1, dtype: object

# %%
reload(dax_process)
# Out:
# <module 'ChromAn.src.file_io.dax_process' from '/lab/weissman_imaging/puzheng/Softwares/ChromAn/src/file_io/dax_process.py'>

# %%
# load one image
_fov_id = 1
_fov_filename = os.path.join(folders[0], fovs[_fov_id])
correction_folder = r'/lab/weissman_imaging/puzheng/Corrections/20231012-Merscope01_s40_n500/'
_loading_params ={
    'CorrectionFolder':correction_folder,
}

# load image
daxp = dax_process.DaxProcesser(
    _fov_filename,
    #CorrectionFolder=correction_folder,
    SaveFilename=os.path.join(analysis_folder, fovs[_fov_id].replace('.dax', '.hdf5')),
    FiducialChannel=color_usage_df.get_fiducial_channel(color_usage_df),
    DapiChannel=color_usage_df.get_dapi_channel(color_usage_df),
    **_loading_params,
    )
daxp._load_image()
# Out:
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/PE_LT/20231012-4T1v21x_50k0927_digestion_test/37c_1day/H0M1/Conv_zscan_001.dax
# - New save file: /lab/weissman_imaging/puzheng/PE_LT/20231012-4T1v21x_50k0927_digestion_test/37c_1day/Analysis/Conv_zscan_001.hdf5
# -- all used channels: ['748', '637', '545', '477', '405']
# -- single image size: [  40 2304 2304]
# - Loaded images for channels:['748', '637', '545', '477', '405'] in 2.192s.

# %%
# run correction
_correction_params = {
    'correction_channels':['748', '637'],
    'corr_drift':False,
    'warp_image':True,
}
daxp.RunCorrection(**_correction_params)
# Out:
# - run bleed correction
# - Start bleedthrough correction for channels:['748', '637', '545', '477'].
# -- loading bleedthrough correction profile from file:bleedthrough_correction_748_637_545_477_2304_2304.npy
# -- corrected bleedthrough for channel 748 in 8.010s.
# -- corrected bleedthrough for channel 637 in 7.930s.
# -- corrected bleedthrough for channel 545 in 7.812s.
# -- corrected bleedthrough for channel 477 in 7.808s.
# - finish bleedthrough correction in 33.916s.
# - run illumination correction
# - Correct illumination for channels: ['748', '637']
# -- Keep channels: ['748', '637'] for corr_illumination.
# - Start illumination correction for channels:['748', '637'].
# -- loading illumination correction profile from file:
# 	 748 illumination_correction_748_2304x2304.npy
# 	 637 illumination_correction_637_2304x2304.npy
# -- corrected illumination for channel 748 in 4.441s.
# -- corrected illumination for channel 637 in 4.204s.
# - Finished illumination correction in 10.895s.
# - run warp correction
# - Start warpping images drift:[], chromatic:['748', '637']
# - Start 3D warpping for channels:['748', '637'].
# -- loading chromatic correction profile from file:
# 	 748 chromatic_correction_748_637_40_2304_2304.npy
# 	 637 None
# -- corrected warp for channel 748 in 30.494s.
# -- corrected warp for channel 637 in 30.166s.
# - Finished warp correction in 89.576s.

# %%
_fitting_params = {'channel_2_seeding_kwargs': {'748': {'th_seed': 2000},'637': {'th_seed': 2000}},
                   'fit_channels':['748','637']
                  }

# %%
# change fitting param
daxp._fit_3D_spots(**_fitting_params, overwrite=True)
# Out:
# -- fit spots in channel: 748, - start SpotFitter seeding
# -- start seeding image, th=2000.00->2000.00, found 89 seeds in 47.39s
# -- start fitting spots with 89 seeds, 89 fitted in 2.706s.
# 89 fitted in 50.110s.
# -- fit spots in channel: 637, - start SpotFitter seeding
# -- start seeding image, th=2000.00->2000.00, found 97 seeds in 47.11s
# -- start fitting spots with 97 seeds, 97 fitted in 2.891s.
# 97 fitted in 50.018s.
# ([Spots3D([[ 5.12673164e+04,  1.21707134e+01,  2.00099170e+03,
#              7.06610565e+01,  6.58416064e+03,  1.33697236e+00,
#              2.42523861e+00,  2.00042272e+00,  5.12359262e-01,
#              1.34385318e-01,  1.84665137e+03],
#            [ 4.18939180e+04,  2.35119486e+00,  2.11363525e+03,
#              1.03083020e+03,  5.10625342e+03,  1.13944399e+00,
#              2.31093454e+00,  1.83344996e+00,  3.51118535e-01,
#              3.36382240e-02,  1.65043823e+03],
#            [ 2.90666270e+04,  7.76913881e+00,  1.33635107e+03,
#              9.82575806e+02,  3.50064282e+03,  1.28844726e+00,
#              2.08570480e+00,  2.06416631e+00,  3.48399282e-01,
#              9.90336612e-02,  8.96393555e+02],
#            [ 2.55698984e+04,  6.17962027e+00,  1.91796716e+03,
#              1.96812805e+03,  3.56623901e+03,  1.30651963e+00,
#              2.50690198e+00,  1.89283097e+00,  3.67329389e-01,
#             -1.43730164e-01,  9.31577759e+02],
#            [ 2.46163809e+04,  6.30994606e+00,  6.59783508e+02,
#              2.16012720e+03,  3.57532007e+03,  1.38985693e+00,
#              1.89927173e+00,  2.12622285e+00,  3.16997975e-01,
#             -2.69457214e-02,  7.84370972e+02],
#            [ 2.43838125e+04,  8.18095016e+00,  5.10375305e+02,
#              1.30915027e+03,  3.32118677e+03,  1.31928968e+00,
#              2.15890741e+00,  1.81559241e+00,  2.17260972e-01,
#             -6.45585358e-02,  7.22159607e+02],
#            [ 2.42657383e+04,  5.84503174e+00,  1.75009253e+03,
#              1.34872827e+03,  2.87718799e+03,  1.18726420e+00,
#              2.07354665e+00,  1.71099567e+00,  3.98331463e-01,
#             -6.30347356e-02,  7.28509033e+02],
#            [ 2.11645254e+04,  1.49788637e+01,  2.05562744e+03,
#              4.10984711e+02,  3.56637646e+03,  1.58281267e+00,
#              3.05697203e+00,  2.00534105e+00,  3.22538704e-01,
#             -1.29825786e-01,  1.01956995e+03],
#            [ 2.39952207e+04,  7.24515438e+00,  1.68432739e+03,
#              6.12178589e+02,  3.09414355e+03,  1.19499087e+00,
#              2.08607578e+00,  1.76031446e+00,  4.56421107e-01,
#              7.80022070e-02,  6.64583374e+02],
#            [ 2.13213984e+04,  8.67593861e+00,  2.04934424e+03,
#              1.22243677e+03,  3.21229150e+03,  1.27230477e+00,
#              2.27370334e+00,  1.68052483e+00,  4.05674398e-01,
#             -2.90624369e-02,  6.62510010e+02],
#            [ 1.95781680e+04,  1.72770271e+01,  1.56638306e+02,
#              5.90497864e+02,  3.67961768e+03,  1.44469345e+00,
#              2.23542237e+00,  1.86026406e+00,  3.84434849e-01,
#              2.34024882e-01,  5.81704224e+02],
#            [ 2.08003398e+04,  4.46782780e+00,  1.44772131e+03,
#              1.43248999e+03,  3.07108936e+03,  1.18544674e+00,
#              2.00351977e+00,  2.71377707e+00,  3.00437748e-01,
#              5.50840907e-02,  7.07532776e+02],
#            [ 2.00849922e+04,  7.09680653e+00,  5.07794098e+02,
#              1.98740454e+03,  2.72381665e+03,  1.78724420e+00,
#              1.35307360e+00,  1.92060173e+00, -9.30375338e-01,
#              6.04724288e-01,  7.52880981e+02],
#            [ 1.82303848e+04,  7.61116171e+00,  2.28626929e+03,
#              1.42880505e+03,  2.84791626e+03,  1.21851027e+00,
#              2.42789435e+00,  1.73839891e+00,  4.71580029e-01,
#             -1.70609821e-02,  5.52372925e+02],
#            [ 1.68675488e+04,  9.20685577e+00,  1.89711792e+03,
#              2.13748682e+03,  2.77001172e+03,  1.22444046e+00,
#              2.24062943e+00,  1.79912341e+00,  4.78659809e-01,
#             -1.70600533e-01,  6.10023193e+02],
#            [ 1.41670469e+04,  2.52201366e+01,  6.75957336e+02,
#              2.14392383e+03,  3.78763086e+03,  2.07654238e+00,
#              1.68497074e+00,  2.42537427e+00, -7.64985263e-01,
#             -9.41919684e-01,  6.83048828e+02],
#            [ 1.64261992e+04,  5.65626907e+00,  1.86312268e+03,
#              2.26249585e+03,  2.84205371e+03,  1.27492476e+00,
#              2.29388666e+00,  1.86149263e+00,  4.12627876e-01,
#             -2.05929324e-01,  6.65146667e+02],
#            [ 1.48501475e+04,  1.85196304e+01,  2.12135205e+03,
#              3.03924042e+02,  3.28754590e+03,  1.40996218e+00,
#              2.44961071e+00,  1.83555138e+00,  4.68430758e-01,
#              2.76588261e-01,  4.50103577e+02],
#            [ 1.54642109e+04,  1.45074892e+01,  1.10394812e+03,
#              1.99907654e+03,  2.32771948e+03,  1.33343303e+00,
#              2.11100769e+00,  1.82130980e+00,  4.91052181e-01,
#             -2.00493321e-01,  4.59066559e+02],
#            [ 1.54812168e+04,  1.22782955e+01,  1.07627686e+03,
#              2.11960254e+03,  2.59350366e+03,  1.30306005e+00,
#              2.04758978e+00,  1.99477935e+00,  5.13289928e-01,
#             -2.30550677e-01,  4.90355042e+02],
#            [ 1.30891758e+04,  2.50719967e+01,  6.75508484e+02,
#              2.14990112e+03,  3.59914087e+03,  1.57291913e+00,
#              2.37157226e+00,  2.28917551e+00,  7.85156310e-01,
#              1.81986229e-03,  6.36143250e+02],
#            [ 1.43055566e+04,  1.27868423e+01,  6.35221924e+02,
#              6.05037048e+02,  2.43412744e+03,  1.36539650e+00,
#              1.97502780e+00,  1.76346588e+00,  3.88453364e-01,
#              2.27653474e-01,  3.85019806e+02],
#            [ 1.38563340e+04,  8.93521786e+00,  8.90396240e+02,
#              2.29028223e+03,  2.85138037e+03,  1.36725807e+00,
#              2.08327150e+00,  2.08066154e+00,  2.48455882e-01,
#             -3.98366034e-01,  4.83519470e+02],
#            [ 1.40183994e+04,  3.26869659e+01,  3.17489258e+02,
#              5.48242859e+02,  2.82041577e+03,  1.55022979e+00,
#              2.11326408e+00,  1.91132498e+00,  7.09881425e-01,
#              1.92597564e-02,  4.00338318e+02],
#            [ 1.33895801e+04,  6.70290661e+00,  2.04034375e+03,
#              8.24272095e+02,  2.48667871e+03,  1.31460023e+00,
#              2.44735932e+00,  1.86057925e+00,  3.48450154e-01,
#              1.87450871e-01,  4.67091461e+02],
#            [ 1.34975771e+04,  1.86589203e+01,  1.60936450e+03,
#              1.91957227e+03,  2.72405713e+03,  1.37190413e+00,
#              2.39568996e+00,  1.79417396e+00,  4.58247572e-01,
#             -1.40560046e-01,  4.20644043e+02],
#            [ 1.34791338e+04,  9.74099350e+00,  2.30216138e+03,
#              1.74122485e+03,  2.19574316e+03,  1.22738254e+00,
#              2.44758034e+00,  1.93734777e+00,  4.88000572e-01,
#             -8.30216780e-02,  3.99282288e+02],
#            [ 1.34397412e+04,  6.82076025e+00,  6.11795654e+02,
#              2.08257471e+03,  2.68756738e+03,  1.31052399e+00,
#              1.96053708e+00,  1.81643438e+00,  2.67655373e-01,
#             -1.68967187e-01,  4.22785889e+02],
#            [ 1.33534766e+04,  1.42875748e+01,  9.57795837e+02,
#              2.24287012e+03,  2.31838843e+03,  1.30905306e+00,
#              2.01286793e+00,  1.82061243e+00,  5.08018553e-01,
#             -2.56819934e-01,  4.42214294e+02],
#            [ 1.28482861e+04,  1.39535265e+01,  3.36965546e+02,
#              1.62941931e+03,  2.08996484e+03,  1.44284022e+00,
#              1.68955255e+00,  1.78825903e+00,  7.22833753e-01,
#             -3.54999214e-01,  4.48918518e+02],
#            [ 1.17770459e+04,  2.22958717e+01,  4.22271149e+02,
#              2.16893457e+03,  2.47300317e+03,  2.81967902e+00,
#              2.05943489e+00,  1.76273012e+00,  3.43679972e-02,
#              5.94014049e-01,  4.22965851e+02],
#            [ 1.25518506e+04,  4.37891150e+00,  1.68401941e+03,
#              1.69403394e+03,  1.93503601e+03,  1.15675616e+00,
#              1.97527075e+00,  1.53984380e+00,  4.00195330e-01,
#             -8.23137909e-02,  4.48397064e+02],
#            [ 1.06242461e+04,  2.51657143e+01,  3.02796173e+02,
#              8.37616638e+02,  3.07649927e+03,  1.53697371e+00,
#              2.37917733e+00,  1.91674960e+00,  6.04248881e-01,
#              1.13895096e-01,  4.01782410e+02],
#            [ 1.14520801e+04,  7.32499123e+00,  1.68304126e+03,
#              6.24603821e+02,  2.38077393e+03,  1.19827843e+00,
#              2.09336305e+00,  1.73083580e+00,  5.12650788e-01,
#              5.79671860e-02,  3.67331116e+02],
#            [ 8.47092969e+03,  2.10442486e+01,  3.09578522e+02,
#              8.38153076e+02,  2.71757202e+03,  1.66858232e+00,
#              2.48886824e+00,  2.05875087e+00,  4.21425372e-01,
#             -3.07120919e-01,  3.59646759e+02],
#            [ 9.49513770e+03,  1.89151134e+01,  1.45764648e+03,
#              2.06175830e+03,  1.88947961e+03,  1.35596693e+00,
#              2.19363761e+00,  1.75671339e+00,  5.17329037e-01,
#             -1.63565472e-01,  3.13187927e+02],
#            [ 9.46509082e+03,  7.37444210e+00,  6.52655273e+02,
#              2.05600122e+03,  1.99538965e+03,  1.30032778e+00,
#              1.80669081e+00,  1.78279686e+00,  3.56893539e-01,
#             -2.40350395e-01,  2.72543640e+02],
#            [ 9.25958301e+03,  1.53512335e+01,  4.41881409e+02,
#              1.89096045e+03,  1.96871606e+03,  1.36133301e+00,
#              1.85781622e+00,  1.77135396e+00,  4.53577548e-01,
#             -2.21238121e-01,  2.63648712e+02],
#            [ 8.82746191e+03,  1.95423527e+01,  4.90694672e+02,
#              1.53418127e+03,  1.93756042e+03,  1.41878629e+00,
#              2.14367199e+00,  1.72027683e+00,  5.00187695e-01,
#             -2.19364718e-01,  2.31656494e+02],
#            [ 9.64144336e+03,  2.94728827e+00,  7.24939758e+02,
#              8.86280884e+02,  1.87393542e+03,  1.07624280e+00,
#              1.79077005e+00,  1.74822295e+00,  1.62184864e-01,
#              4.13488485e-02,  2.24275162e+02],
#            [ 8.98737305e+03,  8.75948143e+00,  1.43038806e+03,
#              1.46424512e+03,  1.76961548e+03,  1.20420611e+00,
#              1.97127938e+00,  1.66690910e+00,  3.59109491e-01,
#             -6.96686730e-02,  2.43864502e+02],
#            [ 8.37591699e+03,  1.02392712e+01,  5.55995178e+02,
#              1.61239087e+03,  1.84455505e+03,  1.29274261e+00,
#              1.88252032e+00,  1.74358582e+00,  3.69708866e-01,
#             -9.06011090e-02,  2.10358566e+02],
#            [ 7.97349316e+03,  1.38539648e+01,  2.16278540e+03,
#              2.05853613e+03,  1.84110486e+03,  1.26346815e+00,
#              2.39512134e+00,  1.73958540e+00,  5.37748933e-01,
#             -1.24523953e-01,  2.70250732e+02],
#            [ 8.03128857e+03,  5.48373318e+00,  1.54000256e+03,
#              1.97868970e+03,  1.59214819e+03,  1.22627163e+00,
#              2.09335041e+00,  1.80805254e+00,  4.10491079e-01,
#             -1.56615809e-01,  2.78662659e+02],
#            [ 7.29903955e+03,  6.55583000e+00,  2.21740649e+03,
#              1.70114148e+03,  1.82798926e+03,  1.25052083e+00,
#              2.35486341e+00,  1.91914463e+00,  4.36567724e-01,
#             -1.59663558e-02,  3.12112183e+02],
#            [ 7.33513232e+03,  1.93531246e+01,  3.87652832e+02,
#              6.21701721e+02,  2.23743896e+03,  1.44408762e+00,
#              2.17469883e+00,  1.92797601e+00,  4.93213683e-01,
#              3.84653121e-01,  2.21089096e+02],
#            [ 7.66473047e+03,  7.49593735e+00,  1.88395239e+03,
#              1.77767346e+03,  1.74908887e+03,  1.23822653e+00,
#              2.25859332e+00,  1.86281681e+00,  4.48142380e-01,
#             -1.83946807e-02,  2.59339539e+02],
#            [ 7.02049658e+03,  2.53060780e+01,  2.28826675e+02,
#              7.22038330e+02,  2.07684033e+03,  1.70931458e+00,
#              1.69541657e+00,  1.66954362e+00, -1.00000000e+00,
#             -1.00000000e+00,  3.03845642e+02],
#            [ 6.87614014e+03,  1.88382378e+01,  1.84350861e+02,
#              5.67746521e+02,  1.75059253e+03,  1.43603468e+00,
#              1.94785058e+00,  1.84991801e+00,  5.63850880e-01,
#              2.69854546e-01,  2.08473114e+02],
#            [ 6.28034521e+03,  2.10973072e+01,  4.88959351e+02,
#              2.26951074e+03,  2.03540576e+03,  1.60795164e+00,
#              2.17606688e+00,  1.95216453e+00,  5.09591281e-01,
#             -1.25106767e-01,  3.34688660e+02],
#            [ 6.58260693e+03,  1.66617546e+01,  1.11942480e+03,
#              2.20889478e+03,  1.86624780e+03,  1.31504953e+00,
#              2.39784145e+00,  1.88113225e+00,  4.60603833e-01,
#             -2.58205473e-01,  2.89727478e+02],
#            [ 6.29553125e+03,  2.99677334e+01,  2.01485376e+03,
#              7.03322205e+02,  1.73750269e+03,  1.74867928e+00,
#              2.55048966e+00,  1.34078276e+00,  6.26000881e-01,
#              1.00000000e+00,  1.81859161e+02],
#            [ 6.53670264e+03,  2.12341309e+00,  6.73246338e+02,
#              1.76337268e+03,  1.50922632e+03,  1.16458511e+00,
#              2.04207993e+00,  2.17217684e+00,  1.91357076e-01,
#             -1.37765914e-01,  2.20503662e+02],
#            [ 6.11981006e+03,  2.18043308e+01,  9.93088745e+02,
#              1.86835132e+03,  1.58830615e+03,  1.30663121e+00,
#              2.00147247e+00,  1.69061959e+00,  6.33172750e-01,
#             -1.05005741e-01,  1.92893509e+02],
#            [ 6.09132568e+03,  2.44071522e+01,  1.71405371e+03,
#              1.57608850e+03,  1.51786890e+03,  1.30369246e+00,
#              2.33537626e+00,  1.73559892e+00,  6.06462359e-01,
#             -1.18223526e-01,  1.85489243e+02],
#            [ 5.71456982e+03,  2.59570198e+01,  2.26899323e+02,
#              7.29868225e+02,  2.04849731e+03,  1.76513505e+00,
#              1.94147933e+00,  1.42963445e+00,  7.82105267e-01,
#             -1.00000000e+00,  2.43532593e+02],
#            [ 6.12212061e+03,  6.61168051e+00,  1.44259851e+03,
#              3.60154236e+02,  1.53388672e+03,  1.26808393e+00,
#              2.09311604e+00,  2.62779808e+00,  3.74869734e-01,
#              1.83181301e-01,  2.39873840e+02],
#            [ 6.09491211e+03,  6.30406761e+00,  1.34229700e+03,
#              6.25195129e+02,  1.46274756e+03,  1.27484775e+00,
#              2.34651375e+00,  1.90416777e+00,  2.58728087e-01,
#              1.97012380e-01,  1.96099976e+02],
#            [ 6.23290039e+03,  3.85341382e+00,  1.74089856e+03,
#              1.99630115e+03,  1.55901758e+03,  1.15831316e+00,
#              1.99527657e+00,  1.76444674e+00,  3.62799227e-01,
#             -9.16093364e-02,  2.43738892e+02],
#            [ 5.79867188e+03,  2.27890072e+01,  2.29989914e+02,
#              2.28269092e+03,  1.88084314e+03,  1.48088396e+00,
#              2.15191746e+00,  1.94267905e+00,  5.73960423e-01,
#             -4.10008103e-01,  2.18362183e+02],
#            [ 5.61801807e+03,  2.19650021e+01,  8.90672058e+02,
#              1.33148499e+02,  1.74384326e+03,  1.41596496e+00,
#              2.21405578e+00,  1.78716242e+00,  5.72801888e-01,
#              2.60755241e-01,  1.94622482e+02],
#            [ 5.76663232e+03,  2.22959175e+01,  3.15082184e+02,
#              1.97746643e+03,  1.86594226e+03,  1.43137872e+00,
#              1.98380709e+00,  1.71380448e+00,  5.34003377e-01,
#             -3.05705398e-01,  1.88007462e+02],
#            [ 5.41560986e+03,  1.35371599e+01,  2.00360010e+03,
#              1.67125098e+03,  1.47059021e+03,  1.36097157e+00,
#              2.39509511e+00,  1.91495728e+00,  5.07468998e-01,
#              2.85760704e-02,  1.89368591e+02],
#            [ 5.64544482e+03,  1.55453405e+01,  5.36692444e+02,
#              6.48199890e+02,  1.68335339e+03,  1.32274485e+00,
#              1.86715388e+00,  1.67031789e+00,  4.80911404e-01,
#              1.23419113e-01,  1.75113953e+02],
#            [ 5.76382861e+03,  4.48295498e+00,  2.00428662e+03,
#              1.56019873e+03,  1.60174390e+03,  1.15772629e+00,
#              2.13291574e+00,  1.75947046e+00,  3.97537321e-01,
#             -4.31790575e-02,  1.96434052e+02],
#            [ 5.51954492e+03,  4.83139849e+00,  1.94603345e+03,
#              5.09279816e+02,  1.60211792e+03,  1.16392851e+00,
#              2.13068914e+00,  1.70071137e+00,  4.07744199e-01,
#              4.39327098e-02,  2.00404083e+02],
#            [ 5.00343066e+03,  1.61289406e+01,  4.36457092e+02,
#              1.00108569e+03,  1.50038367e+03,  1.37826896e+00,
#              1.94871533e+00,  2.05658293e+00,  4.97312099e-01,
#              3.24901864e-02,  1.65639404e+02],
#            [ 5.15842871e+03,  1.22130508e+01,  9.08709793e+01,
#              5.73959839e+02,  1.47890540e+03,  1.41785097e+00,
#              1.80748403e+00,  1.73015296e+00,  4.19910252e-01,
#              4.11318600e-01,  1.72903961e+02],
#            [ 5.39423193e+03,  8.80097198e+00,  7.16607605e+02,
#              9.56722656e+02,  1.35301819e+03,  1.22591984e+00,
#              1.73960781e+00,  1.69216728e+00,  3.19805533e-01,
#              3.25599313e-02,  1.34510651e+02],
#            [ 4.91520703e+03,  1.24601736e+01,  1.38520154e+03,
#              2.21552075e+03,  1.49378369e+03,  1.32601380e+00,
#              2.19584584e+00,  1.85659409e+00,  4.86752093e-01,
#             -2.53009200e-01,  2.00894318e+02],
#            [ 4.36837256e+03,  1.69464188e+01,  1.04173576e+02,
#              7.52336182e+02,  1.75188916e+03,  1.46657825e+00,
#              1.82231271e+00,  1.78809202e+00,  5.90611935e-01,
#              1.23754166e-01,  1.87057541e+02],
#            [ 4.47118604e+03,  2.08374691e+01,  8.69030884e+02,
#              2.07142578e+03,  1.44169202e+03,  1.38280582e+00,
#              2.16337514e+00,  1.81125951e+00,  5.86422801e-01,
#             -2.92089075e-01,  1.66103546e+02],
#            [ 4.58703467e+03,  9.08855343e+00,  2.24192700e+03,
#              1.04195099e+01,  2.01790503e+03,  1.21893299e+00,
#              2.29651952e+00,  1.84373379e+00,  4.56978828e-01,
#              1.04815327e-01,  1.78204437e+02],
#            [ 4.61740430e+03,  1.31017981e+01,  1.69444116e+03,
#              2.24235693e+03,  1.35135608e+03,  1.27949345e+00,
#              2.30149388e+00,  1.80516326e+00,  5.19894540e-01,
#             -1.77041665e-01,  1.65712921e+02],
#            [ 5.01444336e+03,  2.19329834e+00,  1.42853589e+03,
#              9.72870911e+02,  1.59784497e+03,  1.04989100e+00,
#              1.82253158e+00,  1.70559263e+00,  2.58323371e-01,
#              1.03128115e-02,  1.34991028e+02],
#            [ 4.62805859e+03,  5.16643953e+00,  7.46215881e+02,
#              1.99929895e+03,  1.34428894e+03,  1.21110260e+00,
#              1.79357600e+00,  1.76133192e+00,  3.46424013e-01,
#             -1.69143021e-01,  1.46998032e+02],
#            [ 4.54881152e+03,  1.23949928e+01,  1.90948352e+03,
#              2.60127350e+02,  1.60527051e+03,  1.23601079e+00,
#              2.19893146e+00,  1.75062740e+00,  5.35884202e-01,
#              1.10567197e-01,  1.55748169e+02],
#            [ 3.92534570e+03,  1.38594303e+01,  1.33852368e+03,
#              1.75295239e+03,  1.28918298e+03,  1.37700486e+00,
#              2.30884385e+00,  2.18495321e+00,  4.26524848e-01,
#             -1.21084966e-01,  1.77428543e+02],
#            [ 4.18647510e+03,  2.02226524e+01,  1.54361548e+03,
#              2.20677930e+03,  1.45802637e+03,  1.31676960e+00,
#              2.40159392e+00,  2.00096250e+00,  5.84251463e-01,
#             -2.61286318e-01,  1.58479645e+02],
#            [ 3.63942603e+03,  4.60811424e+00,  1.68298047e+03,
#              1.68902002e+03,  1.45949707e+03,  1.47075319e+00,
#              2.55577183e+00,  2.71478152e+00,  3.00212264e-01,
#              1.08370416e-01,  2.66407593e+02],
#            [ 3.44873267e+03,  1.47366085e+01,  3.33016937e+02,
#              1.62683875e+03,  1.45280334e+03,  1.98377764e+00,
#              2.94218111e+00,  2.72353673e+00,  2.58030355e-01,
#              1.62327230e-01,  2.94793549e+02],
#            [ 3.83827417e+03,  7.47487640e+00,  5.02228821e+02,
#              1.98552429e+03,  9.32539246e+02,  4.00000000e+00,
#              3.58385849e+00,  3.03560066e+00,  1.00000000e+00,
#             -5.15760303e-01,  3.46280640e+02],
#            [ 3.78604932e+03,  1.70107441e+01,  1.60686829e+03,
#              1.88156042e+03,  1.35106543e+03,  1.24716663e+00,
#              2.23103213e+00,  1.76801145e+00,  5.37402809e-01,
#             -8.34762305e-02,  1.42158112e+02],
#            [ 3.73653906e+03,  6.67534256e+00,  2.04949023e+03,
#              7.53006516e+01,  1.89404370e+03,  1.19337702e+00,
#              2.36431289e+00,  1.85982025e+00,  4.80325699e-01,
#              1.33319825e-01,  1.29130890e+02],
#            [ 3.41550586e+03,  2.02034397e+01,  1.66364526e+03,
#              2.18626831e+03,  1.28338489e+03,  1.37546778e+00,
#              2.32827353e+00,  1.89740944e+00,  6.02696419e-01,
#             -7.78041258e-02,  1.46334473e+02],
#            [ 3.65611499e+03,  4.52165508e+00,  1.44145740e+03,
#              1.44742456e+03,  1.72725940e+03,  1.13265014e+00,
#              1.75386977e+00,  2.41064262e+00,  3.72725099e-01,
#             -1.33545727e-01,  1.73113098e+02],
#            [ 2.75403687e+03,  6.23472261e+00,  2.00300439e+03,
#              1.44799057e+02,  1.88661536e+03,  1.38190830e+00,
#              2.85069609e+00,  1.86862254e+00,  6.55513644e-01,
#             -7.67348474e-03,  1.04540375e+02],
#            [ 2.71730029e+03,  2.11392937e+01,  4.12869904e+02,
#              5.98645508e+02,  1.71913696e+03,  1.66036057e+00,
#              1.66302013e+00,  1.70017672e+00,  1.00000000e+00,
#              1.00000000e+00,  1.19629074e+02],
#            [ 2.47338428e+03,  1.67731819e+01,  1.10215729e+02,
#              7.58769775e+02,  1.51888635e+03,  1.40765238e+00,
#              2.18342066e+00,  1.82905030e+00,  5.90030432e-01,
#              9.30334628e-02,  1.39945450e+02]], dtype=float32),
#   Spots3D([[ 5.4825051e+04,  1.2145210e+01,  2.0011451e+03, ...,
#              4.7950575e-01,  4.4992633e-02,  2.1930701e+03],
#            [ 6.0996926e+04,  2.3415778e+00,  2.1138564e+03, ...,
#              3.4873387e-01,  7.7996798e-02,  2.4960833e+03],
#            [ 4.7664918e+04,  7.7193894e+00,  1.3362793e+03, ...,
#              3.3363390e-01,  9.9848881e-02,  1.8196855e+03],
#            ...,
#            [ 2.4160647e+03,  6.1877913e+00,  2.0031859e+03, ...,
#             -7.5342828e-01, -5.9427429e-02,  1.6119432e+02],
#            [ 2.9679473e+03,  1.0098855e+01,  5.0832285e+02, ...,
#              3.5608321e-01,  8.0793269e-02,  1.2237947e+02],
#            [ 2.6929827e+03,  8.1800423e+00,  1.9580161e+03, ...,
#              4.8764738e-01,  6.0593050e-02,  1.5356668e+02]], dtype=float32)],
#  ['748', '637'])

# %% [markdown]
# # visual inspection

# %%
# %matplotlib notebook
interactive.imshow_mark_3d([daxp.im_748, daxp.im_637, daxp.im_405], use_dict={
    'class_ids':list(np.zeros(len(daxp.spots_748)))+list(np.ones(len(daxp.spots_637))),
    'coords':list(daxp.spots_748[:,1:4]) + list(daxp.spots_637[:,1:4])}
)
# Out:
# <img src="data:image/png;base64,..." width="399.9999913302337">

# %% [markdown]
# ## Iterrate until good fitting is achieved.

# %% [markdown]
# # Save merged parameters

# %%
# summarize parameter files:
import pickle
merged_parameters = {
    'loading_params': _loading_params,
    'correction_params': _correction_params,
    'fitting_params': _fitting_params,
}
# save
parameter_savefile = os.path.join(analysis_folder, 'H0_preprocessParam.pkl')
print(parameter_savefile)
pickle.dump(merged_parameters, open(parameter_savefile, 'wb'), )
# Out:
# /lab/weissman_imaging/puzheng/PE_LT/20231012-4T1v21x_50k0927_digestion_test/37c_1day/Analysis/H0_preprocessParam.pkl

# %%
# load ref_image
_ref_fov_filename = os.path.join(folders[0], fovs[_fov_id])

ref_daxp = dax_process.DaxProcesser(
    _ref_fov_filename,
    CorrectionFolder=correction_folder,
    SaveFilename=os.path.join(analysis_folder, fovs[_fov_id].replace('.dax', '.hdf5')),
    FiducialChannel=color_usage_df.get_fiducial_channel(color_usage_df),
    )
ref_daxp._load_image()
# Out:
# Initialize DaxProcesser for file:/lab/weissman_imaging/puzheng/PE_LT/20230901-zombie_4T1preEditTop8_low/H0M1/Conv_zscan_01.dax
# - New save file: /lab/weissman_imaging/puzheng/PE_LT/20230901-zombie_4T1preEditTop8_low/Analysis/Conv_zscan_01.hdf5
# -- all used channels: ['748', '637', '545', '477', '405']
# -- single image size: [  30 2304 2304]
# - Loaded images for channels:['748', '637', '545', '477', '405'] in 8.527s.

# %%
daxp.RunCorrection(correction_folder=correction_folder, ref_fiducial_image=ref_daxp.im_477)
# Out:
# - run bleed correction
# - Correct bleedthrough already finished, skip.
# - run illumination correction
# - Correct illumination for channels: ['748', '637', '545', '477']
# - Correct illumination already finished, skip.
# - run drift correction
# + Calculate drift with fiducial_channel: 477
# -- start aligning given source image to given reference image.
# -- drift 0: [0. 0. 0.] in 2.537s.
# -- drift 1: [0. 0. 0.] in 2.702s.
# -- drift 2: [0. 0. 0.] in 2.456s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# - run chromatic correction
# - Generate corr_chromatic_functions for channels: ['748', '637', '545']
# - Keep channels: ['748', '637', '545'] for corr_chromatic_functions.
# - Start generating chromatic correction for channels:['748', '637', '545'].
# -- loading chromatic_constants correction profile from file:
# 	 748 chromatic_correction_748_637_30_2304_2304_const.pkl
# 	 637 None
# 	 545 chromatic_correction_545_637_30_2304_2304_const.pkl
# -- generate chromatic_shift_function for channel: 748 in 0.000s
# -- generate chromatic_shift_function for channel: 637 in 0.000s
# -- generate chromatic_shift_function for channel: 545 in 0.000s
# -- finish generating chromatic functions in 0.002s

# %%
daxp._fit_3D_spots()
# Out:
# -- fit spots in channel: 748,
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:492: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Volumes/weissman_imaging/puzheng/Softwares/Weissman_MERFISH_Scripts/LineageTracing/PrimeEditor_new/Image_Processing/20230913-generate_slurm_parameters.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/Volumes/weissman_imaging/puzheng/Softwares/Weissman_MERFISH_Scripts/LineageTracing/PrimeEditor_new/Image_Processing/20230913-generate_slurm_parameters.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> daxp._fit_3D_spots()
#
# File /lab/weissman_imaging/puzheng/Softwares/ChromAn/src/file_io/dax_process.py:980, in DaxProcesser._fit_3D_spots(self, fit_channels, channel_2_seeding_kwargs, fitting_mode, channel_2_seeds, channel_2_fitting_kwargs, normalization, normalization_kwargs, overwrite, detailed_verbose)
#     978 # fitting
#     979 if fitting_mode == 'cpu':
# --> 980     _fitter.CPU_fitting(
#     981         remove_boundary_points=False,
#     982         normalization=normalization,
#     983         normalization_kwargs=normalization_kwargs,
#     984     )
#     985 # retrive spots
#     986 _spots = _fitter.spots.copy()
#
# File /lab/weissman_imaging/puzheng/Softwares/ChromAn/src/spot_tools/spot_fitting.py:87, in SpotFitter.CPU_fitting(self, fitting_kwargs, remove_boundary_points, normalization, normalization_kwargs)
#      81 _fitter = iter_fit_seed_points(
#      82     self.image, self.seeds.to_coords().T,
#      83     #init_w=init_sigma, weight_sigma=weight_sigma,
#      84     **_fitting_kwargs,
#      85 )
#      86 # fit
# ---> 87 _fitter.firstfit()
#      88 # check
#      89 _fitter.repeatfit()
#
# File /lab/weissman_imaging/puzheng/Softwares/ChromAn/src/spot_tools/bintu_fitting.py:926, in iter_fit_seed_points.firstfit(self)
#     922 self.gparms
#     924 obj = GaussianFit(im_,X,center=center,delta_center=self.min_delta_center,
#     925                   min_w=self.min_w, max_w=self.max_w, init_w=self.init_w)
# --> 926 obj.fit()
#     928 self.gparms.append([im_,X,center])
#     929 n_p = len(obj.p)
#
# File /lab/weissman_imaging/puzheng/Softwares/ChromAn/src/spot_tools/bintu_fitting.py:693, in GaussianFit.fit(self, eps_frac, eps_dist, eps_angle)
#     691 parms0 = self.p_
#     692 self.p_old = None
# --> 693 parmsf,_ = leastsq(self.calc_eps,parms0,Dfun=self.calc_jac, maxfev=1000) # changed maxfev to block warning message
#     694 #parmsf=parms0#####pisici
#     695 self.p_ = parmsf
#
# File /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:435, in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     433     if maxfev == 0:
#     434         maxfev = 100 * (n + 1)
# --> 435     retval = _minpack._lmder(func, Dfun, x0, args, full_output,
#     436                              col_deriv, ftol, xtol, gtol, maxfev,
#     437                              factor, diag)
#     439 errors = {0: ["Improper input parameters.", TypeError],
#     440           1: ["Both actual and predicted relative reductions "
#     441               "in the sum of squares\n  are at most %f" % ftol, None],
#    (...)
#     460               "columns of\n  the Jacobian to machine "
#     461               "precision." % gtol, ValueError]}
#     463 # The FORTRAN return value (possible return values are >= 0 and <= 8)
#
# File /lab/weissman_imaging/puzheng/Softwares/ChromAn/src/spot_tools/bintu_fitting.py:630, in GaussianFit.calc_jac(self, parms)
#     628 t,p = self.to_sine(tp),self.to_sine(pp)
#     629 ws1,ws2,ws3 = self.to_ws(w1),self.to_ws(w2),self.to_ws(w3)
# --> 630 xc,yc,zc = self.to_center(xp,yp,zp)
#     631 xt,yt,zt = self.x-xc,self.y-yc,self.z-zc
#     632 p2 = p*p
#
# File /lab/weissman_imaging/puzheng/Softwares/ChromAn/src/spot_tools/bintu_fitting.py:512, in GaussianFit.to_center(self, c0_, c1_, c2_)
#     510     c1 = 2. *delta / (1.+np.exp(c1_)) - delta + self.center_est[1]
#     511 # c2
# --> 512 if c2_ >= np.log(np.finfo(c2_.dtype).max):
#     513     c2 = - delta + self.center_est[2]
#     514 elif c2_ <= - np.log(np.finfo(c2_.dtype).max):
#
# File /lab/weissman_imaging/puzheng/.conda/env/postanalysis/lib/python3.10/site-packages/numpy/core/getlimits.py:460, in finfo.__new__(cls, dtype)
#     458 def __new__(cls, dtype):
#     459     try:
# --> 460         dtype = numeric.dtype(dtype)
#     461     except TypeError:
#     462         # In case a float instance was given
#     463         dtype = numeric.dtype(type(dtype))
#
# KeyboardInterrupt:

# %%
import warnings
def handle_warning(message, category, filename, lineno, file=None, line=None):
    print('A warning occurred:')
    print(message)
    print('Do you wish to continue?')

    while True:
        response = input('y/n: ').lower()
        if response not in {'y', 'n'}:
            print('Not understood.')
        else:
            break

    if response == 'n':
        raise category(message)
    
def pause_if_warning(function, *args, **kwargs):
    with warnings.catch_warnings(category=RuntimeWarning):
        warnings.showwarning = handle_warning
        return function(*args, **kwargs)

# %%
for _channel, _info in image_infos.items():
    with warnings.catch_warnings():
        print(_channel, _info)
        warnings.warn('test', category=RuntimeWarning)
# Out:
# 748 r2
# 637 m53
# 545 empty
# 477 beads
# 405 DAPI
# /tmp/ipykernel_1285990/272236076.py:4: RuntimeWarning: test
#   warnings.warn('test', category=RuntimeWarning)
# /tmp/ipykernel_1285990/272236076.py:4: RuntimeWarning: test
#   warnings.warn('test', category=RuntimeWarning)
# /tmp/ipykernel_1285990/272236076.py:4: RuntimeWarning: test
#   warnings.warn('test', category=RuntimeWarning)
# /tmp/ipykernel_1285990/272236076.py:4: RuntimeWarning: test
#   warnings.warn('test', category=RuntimeWarning)
# /tmp/ipykernel_1285990/272236076.py:4: RuntimeWarning: test
#   warnings.warn('test', category=RuntimeWarning)

# %%
color_usage_df.get_hyb_id('H0M1')
# Out:
# 0

# %%
os.listdir(analysis_folder)
# Out:
# ['color_usage_v2.csv', 'Color_Usage.csv']
